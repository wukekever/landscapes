# %%
import numpy as np
import random
from math import *
import time

import copy

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR

# %%
torch.cuda.set_device(1)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build ResNet with three blocks
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        self.layer1 = torch.nn.Linear(layer_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer3 = torch.nn.Linear(layer_width, layer_width)
        self.layer4 = torch.nn.Linear(layer_width, layer_width)
        self.layer5 = torch.nn.Linear(layer_width, layer_width)
        self.layer6 = torch.nn.Linear(layer_width, layer_width)
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        y = self.layer_in(x)
        y = y + activation(self.layer2(activation(self.layer1(y)))) # residual block 1
        y = y + activation(self.layer4(activation(self.layer3(y)))) # residual block 2
        y = y + activation(self.layer6(activation(self.layer5(y)))) # residual block 3
        output = self.layer_out(y)
        return output

# %%
dimension = 3

# %%
input_width,layer_width = dimension, 8

# %%
net = Net(input_width,layer_width).cuda() # network for u on gpu

# %%
# defination of exact solution
def u_ex(x):  
    x_norm = torch.norm(x, dim = 1) # compute norm of x; dim = 1 - > sum by row
    u_x = torch.sin(pi/2*(1-x_norm)).reshape([x.size()[0],1])
    return u_x

# %%
# defination of f(x)
def f(x):
    x_norm = torch.norm(x, dim = 1)
    f_temp = 1/4*pi**2*torch.sin(pi/2*(1-x_norm)) + 1/2*pi*(dimension-1)/x_norm*torch.cos(pi/2*(1-x_norm))  
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    i = 0
    x = torch.tensor([])
    while x.size()[0] < data_size:
        temp_x = 2*torch.rand(data_size, dimension) - 1
        index = torch.where(torch.norm(temp_x, dim = 1) < 1)
        temp_x = temp_x[index]
        x = torch.cat((x,temp_x),0)
    x = x[1:data_size, :]
    return x

# %%
def model(x):
    x_norm = torch.norm(x, p = 2, dim = 1) 
    return (1-x_norm**2).reshape([x.size()[0], 1]) * net(x)

# %%
# loss function to DRM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape).cuda(), create_graph = True)
    grad_u_sq = ((grad_u_hat[0]**2).sum(1)).reshape([len(grad_u_hat[0]), 1])
    part = torch.sum(0.5 * grad_u_sq  - f(x) * u_hat)  / len(x)
    return part

# %%
data_size = 1000
x = generate_sample(data_size).cuda()
x.requires_grad = True

# %%
def relative_l2_error():
    data_size_temp = 500
    x = generate_sample(data_size_temp).cuda() 
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
optimizer = optim.Adam(net.parameters())

# %%
epoch = 5000
data_size = 1000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size).cuda()
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    np.save("DRM_loss_3d.npy", loss_record)
    np.save("DRM_error_3d.npy", error_record)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    if i == epoch - 1:
        # save model parameters
        torch.save(net.state_dict(), 'net_params_DRM.pkl')
        
    loss.backward()
    optimizer.step() 
    torch.cuda.empty_cache() # clear memory
    
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(-0.5462, device='cuda:1')
# current error is:  tensor(0.6347, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(-1.0517, device='cuda:1')
# current error is:  tensor(0.1249, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(-0.9070, device='cuda:1')
# current error is:  tensor(0.0675, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(-0.9350, device='cuda:1')
# current error is:  tensor(0.0503, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(-0.9763, device='cuda:1')
# current error is:  tensor(0.0477, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(-1.0259, device='cuda:1')
# current error is:  tensor(0.0532, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(-0.8722, device='cuda:1')
# current error is:  tensor(0.0602, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(-1.0304, device='cuda:1')
# current error is:  tensor(0.0475, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(-1.0716, device='cuda:1')
# current error is:  tensor(0.0487, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(-0.9987, device='cuda:1')
# current error is:  tensor(0.0559, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(-0.9085, device='cuda:1')
# current error is:  tensor(0.0518, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(-1.0473, device='cuda:1')
# current error is:  tensor(0.0497, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(-0.8173, device='cuda:1')
# current error is:  tensor(0.0458, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(-0.9537, device='cuda:1')
# current error is:  tensor(0.0581, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(-1.1047, device='cuda:1')
# current error is:  tensor(0.0533, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(-1.0503, device='cuda:1')
# current error is:  tensor(0.0424, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(-0.9076, device='cuda:1')
# current error is:  tensor(0.0441, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(-1.0090, device='cuda:1')
# current error is:  tensor(0.0409, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(-1.0252, device='cuda:1')
# current error is:  tensor(0.0385, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(-0.9338, device='cuda:1')
# current error is:  tensor(0.0462, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-1.0493, device='cuda:1')
# current error is:  tensor(0.0465, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-1.0142, device='cuda:1')
# current error is:  tensor(0.0380, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-0.9256, device='cuda:1')
# current error is:  tensor(0.0388, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-1.0617, device='cuda:1')
# current error is:  tensor(0.0320, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-0.9822, device='cuda:1')
# current error is:  tensor(0.0316, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-1.0097, device='cuda:1')
# current error is:  tensor(0.0304, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-0.9942, device='cuda:1')
# current error is:  tensor(0.0300, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-1.0115, device='cuda:1')
# current error is:  tensor(0.0429, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-0.9534, device='cuda:1')
# current error is:  tensor(0.0447, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-0.9766, device='cuda:1')
# current error is:  tensor(0.0244, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-1.0065, device='cuda:1')
# current error is:  tensor(0.0343, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-1.1527, device='cuda:1')
# current error is:  tensor(0.0241, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-0.9208, device='cuda:1')
# current error is:  tensor(0.0319, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-0.9833, device='cuda:1')
# current error is:  tensor(0.0265, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-0.9703, device='cuda:1')
# current error is:  tensor(0.0292, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-0.8968, device='cuda:1')
# current error is:  tensor(0.0197, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-0.9774, device='cuda:1')
# current error is:  tensor(0.0164, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-1.0914, device='cuda:1')
# current error is:  tensor(0.0120, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-1.0673, device='cuda:1')
# current error is:  tensor(0.0262, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-0.9626, device='cuda:1')
# current error is:  tensor(0.0103, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-0.8889, device='cuda:1')
# current error is:  tensor(0.0099, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-0.9866, device='cuda:1')
# current error is:  tensor(0.0123, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-0.9389, device='cuda:1')
# current error is:  tensor(0.0091, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-0.9611, device='cuda:1')
# current error is:  tensor(0.0063, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-0.9941, device='cuda:1')
# current error is:  tensor(0.0067, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-1.0917, device='cuda:1')
# current error is:  tensor(0.0177, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-1.1271, device='cuda:1')
# current error is:  tensor(0.0143, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-0.9346, device='cuda:1')
# current error is:  tensor(0.0078, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-0.8552, device='cuda:1')
# current error is:  tensor(0.0122, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-0.9131, device='cuda:1')
# current error is:  tensor(0.0090, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-0.9815, device='cuda:1')
# current error is:  tensor(0.0130, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-1.0260, device='cuda:1')
# current error is:  tensor(0.0311, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-0.9773, device='cuda:1')
# current error is:  tensor(0.0063, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-1.0103, device='cuda:1')
# current error is:  tensor(0.0220, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-0.9600, device='cuda:1')
# current error is:  tensor(0.0108, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-1.0297, device='cuda:1')
# current error is:  tensor(0.0153, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-0.9884, device='cuda:1')
# current error is:  tensor(0.0133, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-1.0394, device='cuda:1')
# current error is:  tensor(0.0190, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-1.1697, device='cuda:1')
# current error is:  tensor(0.0135, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-1.0001, device='cuda:1')
# current error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-0.9569, device='cuda:1')
# current error is:  tensor(0.0285, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-0.9074, device='cuda:1')
# current error is:  tensor(0.0176, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-1.0246, device='cuda:1')
# current error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-0.9839, device='cuda:1')
# current error is:  tensor(0.0107, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-0.9754, device='cuda:1')
# current error is:  tensor(0.0199, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-1.0674, device='cuda:1')
# current error is:  tensor(0.0160, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-0.9884, device='cuda:1')
# current error is:  tensor(0.0112, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-0.9881, device='cuda:1')
# current error is:  tensor(0.0110, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-0.9816, device='cuda:1')
# current error is:  tensor(0.0112, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-0.9245, device='cuda:1')
# current error is:  tensor(0.0120, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-0.9669, device='cuda:1')
# current error is:  tensor(0.0103, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-1.0580, device='cuda:1')
# current error is:  tensor(0.0084, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-0.9230, device='cuda:1')
# current error is:  tensor(0.0266, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-1.0997, device='cuda:1')
# current error is:  tensor(0.0149, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-0.9745, device='cuda:1')
# current error is:  tensor(0.0128, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-0.9860, device='cuda:1')
# current error is:  tensor(0.0197, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-0.9903, device='cuda:1')
# current error is:  tensor(0.0084, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-1.1156, device='cuda:1')
# current error is:  tensor(0.0114, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-0.9576, device='cuda:1')
# current error is:  tensor(0.0116, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-1.0005, device='cuda:1')
# current error is:  tensor(0.0048, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-0.9736, device='cuda:1')
# current error is:  tensor(0.0216, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-1.1074, device='cuda:1')
# current error is:  tensor(0.0080, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-1.0691, device='cuda:1')
# current error is:  tensor(0.0146, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-1.0446, device='cuda:1')
# current error is:  tensor(0.0224, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-1.0125, device='cuda:1')
# current error is:  tensor(0.0223, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-1.0020, device='cuda:1')
# current error is:  tensor(0.0219, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-0.9261, device='cuda:1')
# current error is:  tensor(0.0091, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-0.9950, device='cuda:1')
# current error is:  tensor(0.0172, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-1.0091, device='cuda:1')
# current error is:  tensor(0.0122, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-1.0179, device='cuda:1')
# current error is:  tensor(0.0048, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-1.1286, device='cuda:1')
# current error is:  tensor(0.0086, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-0.9897, device='cuda:1')
# current error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-0.9507, device='cuda:1')
# current error is:  tensor(0.0254, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-1.0786, device='cuda:1')
# current error is:  tensor(0.0047, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-0.9832, device='cuda:1')
# current error is:  tensor(0.0129, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-0.8753, device='cuda:1')
# current error is:  tensor(0.0071, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-0.9892, device='cuda:1')
# current error is:  tensor(0.0113, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-1.0040, device='cuda:1')
# current error is:  tensor(0.0107, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-1.0510, device='cuda:1')
# current error is:  tensor(0.0236, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-0.9814, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# total time is:  108.32016825675964 seconds
