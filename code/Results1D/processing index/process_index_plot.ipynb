# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Epoch = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]

# %%
DGM_index = [0.001, 0.186, 0.219, 0.180, 0.107, 0.079, 0.029, 0.029, 0.038, 0.029, 0.020]
DRM_index = [0.065, 0.018, 0.103, 0.002, 0.136, 0.196, 0.105, 0.159, 0.196, 0.208, 0.173]

# %%
plt.style.use("seaborn-dark")
fig = plt.figure()
ax = plt.subplot(1,1,1)

ax.plot(Epoch, DRM_index, color = 'r', marker = '*', label = 'DRM')
ax.plot(Epoch, DGM_index, color = 'g', marker = 'o', label = 'DGM')

# for xy in zip(Epoch, DGM_index):
#     plt.annotate("(%s, %s)" % xy, xy = xy, xytext = (4, 2), textcoords = 'offset points')

# for xy in zip(Epoch, DRM_index):
#     plt.annotate("(%s, %s)" % xy, xy = xy, xytext = (4, -2), textcoords = 'offset points')
    
plt.xlabel('Epoch', size = 14)
plt.ylabel('Roughness index', size = 14)
plt.grid(True)
plt.legend()
plt.savefig("process_index.eps", dpi = 120)
plt.savefig("process_index.pdf", dpi = 120)
plt.show()
