# %%
import numpy as np
import random
from math import *
import time

import copy

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        output = self.layer_out(x)
        return output

# %%
dimension = 1

# %%
input_width,layer_width = dimension, 1

# %%
net = Net(input_width,layer_width)

# %%
# defination of exact solution
def u_ex(x):     
    u_temp = 2*x**3 - x**2 - x
    return u_temp.reshape([x.size()[0], 1])

# %%
# defination of f(x)
def f(x):
    f_temp = -(12*x - 2)
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp

# %%
def model(x):
    x_temp = x
    D_x_0 = torch.prod(x_temp, axis = 1).reshape([x.size()[0], 1]) 
    D_x_1 = torch.prod(1.0 - x_temp, axis = 1).reshape([x.size()[0], 1]) 
    model_u_temp = D_x_0 * D_x_1 * net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %%
# loss function to DGM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape), create_graph = True)
    laplace_u = torch.zeros([len(grad_u_hat[0]), 1])
    for index in range(dimension):
        p_temp = grad_u_hat[0][:, index].reshape([len(grad_u_hat[0]), 1])
        temp = torch.autograd.grad(outputs = p_temp, inputs = x, grad_outputs = torch.ones(p_temp.shape), create_graph = True, allow_unused = True)[0]
        laplace_u = temp[:, index].reshape([len(grad_u_hat[0]), 1]) + laplace_u
        part_2 = torch.sum((-laplace_u - f(x))**2)  / len(x)
    return part_2

# %%
data_size = 10000
x = generate_sample(data_size)
x.requires_grad = True

# %%
def get_weights(net):
    """ Extract parameters from net, and return a list of tensors"""
    return [p.data for p in net.parameters()]

# %%
def set_weights(net, weights, directions=None, step=None):
    """
        Overwrite the network's weights with a specified list of tensors
        or change weights along directions with a step size.
    """
    if directions is None:
        # You cannot specify a step length without a direction.
        for (p, w) in zip(net.parameters(), weights):
            p.data.copy_(w.type(type(p.data)))
    else:
        assert step is not None, 'If a direction is specified then step must be specified as well'

        if len(directions) == 2:
            dx = directions[0]
            dy = directions[1]
            changes = [d0*step[0] + d1*step[1] for (d0, d1) in zip(dx, dy)]
        else:
            changes = [d*step for d in directions[0]]

        for (p, w, d) in zip(net.parameters(), weights, changes):
            p.data = w + torch.Tensor(d).type(type(w))

# %%
def set_states(net, states, directions=None, step=None):
    """
        Overwrite the network's state_dict or change it along directions with a step size.
    """
    if directions is None:
        net.load_state_dict(states)
    else:
        assert step is not None, 'If direction is provided then the step must be specified as well'
        if len(directions) == 2:
            dx = directions[0]
            dy = directions[1]
            changes = [d0*step[0] + d1*step[1] for (d0, d1) in zip(dx, dy)]
        else:
            changes = [d*step for d in directions[0]]

        new_states = copy.deepcopy(states)
        assert (len(new_states) == len(changes))
        for (k, v), d in zip(new_states.items(), changes):
            d = torch.tensor(d)
            v.add_(d.type(v.type()))

        net.load_state_dict(new_states)

# %%
def get_random_weights(weights):
    """
        Produce a random direction that is a list of random Gaussian tensors
        with the same shape as the network's weights, so one direction entry per weight.
    """
    return [torch.randn(w.size()) for w in weights]

# %%
def get_random_states(states):
    """
        Produce a random direction that is a list of random Gaussian tensors
        with the same shape as the network's state_dict(), so one direction entry
        per weight, including BN's running_mean/var.
    """
    return [torch.randn(w.size()) for k, w in states.items()]

# %%
def get_diff_weights(weights, weights2):
    """ Produce a direction from 'weights' to 'weights2'."""
    return [w2 - w for (w, w2) in zip(weights, weights2)]

# %%
def get_diff_states(states, states2):
    """ Produce a direction from 'states' to 'states2'."""
    return [v2 - v for (k, v), (k2, v2) in zip(states.items(), states2.items())]

# %%
def normalize_direction(direction, weights, norm='filter'):
    """
        Rescale the direction so that it has similar norm as their corresponding
        model in different levels.
        Args:
          direction: a variables of the random direction for one layer
          weights: a variable of the original model for one layer
          norm: normalization method, 'filter' | 'layer' | 'weight'
    """
    if norm == 'filter':
        # Rescale the filters (weights in group) in 'direction' so that each
        # filter has the same norm as its corresponding filter in 'weights'.
        for d, w in zip(direction, weights):
            d.mul_(w.norm()/(d.norm() + 1e-10))
    elif norm == 'layer':
        # Rescale the layer variables in the direction so that each layer has
        # the same norm as the layer variables in weights.
        direction.mul_(weights.norm()/direction.norm())
    elif norm == 'weight':
        # Rescale the entries in the direction so that each entry has the same
        # scale as the corresponding weight.
        direction.mul_(weights)
    elif norm == 'dfilter':
        # Rescale the entries in the direction so that each filter direction
        # has the unit norm.
        for d in direction:
            d.div_(d.norm() + 1e-10)
    elif norm == 'dlayer':
        # Rescale the entries in the direction so that each layer direction has
        # the unit norm.
        direction.div_(direction.norm())

# %%
def normalize_directions_for_weights(direction, weights, norm='filter', ignore='biasbn'):
    """
        The normalization scales the direction entries according to the entries of weights.
    """
    assert(len(direction) == len(weights))
    for d, w in zip(direction, weights):
        if d.dim() <= 1:
            if ignore == 'biasbn':
                d.fill_(0) # ignore directions for weights with 1 dimension
            else:
                d.copy_(w) # keep directions for weights/bias that are only 1 per node
        else:
            normalize_direction(d, w, norm)

# %%
def normalize_directions_for_states(direction, states, norm='filter', ignore='ignore'):
    assert(len(direction) == len(states))
    for d, (k, w) in zip(direction, states.items()):
        if d.dim() <= 1:
            if ignore == 'biasbn':
                d.fill_(0) # ignore directions for weights with 1 dimension
            else:
                d.copy_(w) # keep directions for weights/bias that are only 1 per node
        else:
            normalize_direction(d, w, norm)

# %%
def ignore_biasbn(directions):
    """ Set bias and bn parameters in directions to zero """
    for d in directions:
        if d.dim() <= 1:
            d.fill_(0)

# %%
def create_random_direction(net, dir_type='weights', ignore='biasbn', norm='filter'):
    """
        Setup a random (normalized) direction with the same dimension as
        the weights or states.
        Args:
          net: the given trained model
          dir_type: 'weights' or 'states', type of directions.
          ignore: 'biasbn', ignore biases and BN parameters.
          norm: direction normalization method, including
                'filter" | 'layer' | 'weight' | 'dlayer' | 'dfilter'
        Returns:
          direction: a random direction with the same dimension as weights or states.
    """

    # random direction
    if dir_type == 'weights':
        weights = get_weights(net) # a list of parameters.
        direction = get_random_weights(weights)
        normalize_directions_for_weights(direction, weights, norm, ignore)
    elif dir_type == 'states':
        states = net.state_dict() # a dict of parameters, including BN's running mean/var.
        direction = get_random_states(states)
        normalize_directions_for_states(direction, states, norm, ignore)

    return direction

# %%
def tvd(m, l_i):
    
    # load model parameters
    pretrained_dict = torch.load('net_params_DGM.pkl')
    
    # get state_dict
    net_state_dict = net.state_dict()

    # remove keys that does not belong to net_state_dict
    pretrained_dict_1 = {k: v for k, v in pretrained_dict.items() if k in net_state_dict}

    # update dict
    net_state_dict.update(pretrained_dict_1)

    # set new dict back to net
    net.load_state_dict(net_state_dict)
    
    weights_temp = get_weights(net)
    states_temp = net.state_dict()
    
    step_size = 2 * l_i / m  
    grid = np.arange(-l_i, l_i + step_size, step_size)
    num_direction = 1
    loss_matrix = torch.zeros((num_direction, len(grid)))

    for temp in range(num_direction):
        weights = weights_temp
        states = states_temp
        direction_temp = create_random_direction(net, dir_type='weights', ignore='biasbn', norm='filter')
        normalize_directions_for_states(direction_temp, states, norm='filter', ignore='ignore')
        directions = [direction_temp]

        for dx in grid:
            itemindex_1 = np.argwhere(grid == dx)
            step = dx

            set_states(net, states, directions, step)
            loss_temp = loss_function(x)
            loss_matrix[temp, itemindex_1[0]] = loss_temp
            
            # clear memory
            torch.cuda.empty_cache()

            # get state_dict
            net_state_dict = net.state_dict()
            # remove keys that does not belong to net_state_dict
            pretrained_dict_1 = {k: v for k, v in pretrained_dict.items() if k in net_state_dict}
            # update dict
            net_state_dict.update(pretrained_dict_1)
            # set new dict back to net
            net.load_state_dict(net_state_dict)
            weights_temp = get_weights(net)
            states_temp = net.state_dict()

    interval_length = grid[-1] - grid[0]
    TVD = 0.0
    for temp in range(num_direction):
        for index in range(loss_matrix.size()[1] - 1):
            TVD = TVD + np.abs(float(loss_matrix[temp, index] - loss_matrix[temp, index + 1]))
    Max = np.max(loss_matrix.detach().numpy())
    Min = np.min(loss_matrix.detach().numpy())

    TVD = TVD / interval_length / num_direction / (Max - Min)

    return TVD, Max, Min

# %%
M = 100
m = 50
l_i = 2.0

TVD_DGM = 0.0

time_start = time.time()

Max = []
Min = []
Result = []

for count in range(M):
    TVD_temp, Max_temp, Min_temp = tvd(m, l_i)
#     print(Max_temp, Min_temp)
    Max.append(Max_temp)
    Min.append(Min_temp)
    Result.append(TVD_temp)
    print('Current direction TVD of DGM is: ', TVD_temp)
    TVD_DGM = TVD_DGM + TVD_temp
    print((count + 1) / M * 100, '% finished.')

# print('Max of all is: ', np.max(Max))
# print('Min of all is: ', np.min(Min))

TVD_DGM = TVD_DGM / M 
print('All directions average TVD of DGM is: ', TVD_DGM)

print('Variance TVD of DGM is: ', np.sqrt(np.var(Result, ddof = 1)))

time_end = time.time()
print('Total time costs: ', time_end - time_start, 'seconds')
# Out:
# /home/keke/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Current direction TVD of DGM is:  0.49999997446052113
# 1.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 2.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 3.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 4.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 5.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 6.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 7.000000000000001 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 8.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 9.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 10.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 11.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 12.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 13.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 14.000000000000002 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 15.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 16.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 17.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 18.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 19.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 20.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 21.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 22.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 23.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 24.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 25.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 26.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 27.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 28.000000000000004 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 28.999999999999996 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 30.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 31.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 32.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 33.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 34.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 35.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 36.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 37.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 38.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 39.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 40.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 41.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 42.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 43.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 44.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 45.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 46.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 47.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 48.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 49.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 50.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 51.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 52.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 53.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 54.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 55.00000000000001 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 56.00000000000001 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 56.99999999999999 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 57.99999999999999 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 59.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 60.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 61.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 62.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 63.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 64.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 65.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 66.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 67.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 68.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 69.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 70.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 71.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 72.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 73.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 74.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 75.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 76.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 77.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 78.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 79.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 80.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 81.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 82.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 83.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 84.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 85.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 86.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 87.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 88.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 89.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 90.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 91.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 92.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 93.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 94.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 95.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 96.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 97.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 98.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279437
# 99.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 100.0 % finished.
# All directions average TVD of DGM is:  0.49999983012425553
# Variance TVD of DGM is:  1.3660571313837712e-07
# Total time costs:  225.28293180465698 seconds

# %%
1.3660571313837712e-07 / 0.49999983012425553
# Out:
# 2.7321151910077463e-07

# %%
M = 100
m = 100
l_i = 2.0

TVD_DGM = 0.0

time_start = time.time()

Max = []
Min = []
Result = []

for count in range(M):
    TVD_temp, Max_temp, Min_temp = tvd(m, l_i)
#     print(Max_temp, Min_temp)
    Max.append(Max_temp)
    Min.append(Min_temp)
    Result.append(TVD_temp)
    print('Current direction TVD of DGM is: ', TVD_temp)
    TVD_DGM = TVD_DGM + TVD_temp
    print((count + 1) / M * 100, '% finished.')

# print('Max of all is: ', np.max(Max))
# print('Min of all is: ', np.min(Min))

TVD_DGM = TVD_DGM / M 
print('All directions average TVD of DGM is: ', TVD_DGM)

print('Variance TVD of DGM is: ', np.sqrt(np.var(Result, ddof = 1)))

time_end = time.time()
print('Total time costs: ', time_end - time_start, 'seconds')
# Out:
# /home/keke/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Current direction TVD of DGM is:  0.4999999744605212
# 1.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 2.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 3.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 4.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 5.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 6.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 7.000000000000001 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 8.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 9.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 10.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 11.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 12.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 13.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 14.000000000000002 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 15.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 16.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 17.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 18.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 19.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 20.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 21.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 22.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 23.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 24.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 25.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 26.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 27.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 28.000000000000004 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 28.999999999999996 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 30.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 31.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 32.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 33.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 34.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 35.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 36.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 37.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 38.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 39.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 40.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 41.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 42.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 43.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 44.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 45.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 46.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 47.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 48.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 49.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 50.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 51.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 52.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 53.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 54.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 55.00000000000001 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 56.00000000000001 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 56.99999999999999 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 57.99999999999999 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 59.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 60.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 61.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 62.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 63.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 64.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 65.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 66.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 67.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 68.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 69.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 70.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 71.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 72.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 73.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 74.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 75.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 76.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 77.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 78.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 79.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 80.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 81.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 82.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 83.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 84.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 85.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 86.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 87.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 88.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 89.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 90.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 91.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 92.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 93.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 94.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 95.0 % finished.
# Current direction TVD of DGM is:  0.4999999744605212
# 96.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 97.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 98.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 99.0 % finished.
# Current direction TVD of DGM is:  0.4999997021279438
# 100.0 % finished.
# All directions average TVD of DGM is:  0.4999998437408844
# Variance TVD of DGM is:  1.3674274365267008e-07
# Total time costs:  363.42047929763794 seconds

# %%
1.3674274365267008e-07 / 0.4999998437408844
# Out:
# 2.734855727745676e-07

# %%
M = 100
m = 25
l_i = 2.0

TVD_DGM = 0.0

time_start = time.time()

Max = []
Min = []
Result = []

for count in range(M):
    TVD_temp, Max_temp, Min_temp = tvd(m, l_i)
#     print(Max_temp, Min_temp)
    Max.append(Max_temp)
    Min.append(Min_temp)
    Result.append(TVD_temp)
    print('Current direction TVD of DGM is: ', TVD_temp)
    TVD_DGM = TVD_DGM + TVD_temp
    print((count + 1) / M * 100, '% finished.')

# print('Max of all is: ', np.max(Max))
# print('Min of all is: ', np.min(Min))

TVD_DGM = TVD_DGM / M 
print('All directions average TVD of DGM is: ', TVD_DGM)

print('Variance TVD of DGM is: ', np.sqrt(np.var(Result, ddof = 1)))

time_end = time.time()
print('Total time costs: ', time_end - time_start, 'seconds')
# Out:
# /home/keke/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Current direction TVD of DGM is:  0.49999997441959426
# 1.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 2.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 3.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 4.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 5.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 6.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 7.000000000000001 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 8.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 9.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 10.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 11.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 12.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 13.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 14.000000000000002 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 15.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 16.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 17.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 18.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 19.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 20.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 21.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 22.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 23.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 24.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 25.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 26.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 27.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 28.000000000000004 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 28.999999999999996 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 30.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 31.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 32.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 33.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 34.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 35.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 36.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 37.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 38.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 39.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 40.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 41.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 42.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 43.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 44.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 45.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 46.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 47.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 48.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 49.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 50.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 51.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 52.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 53.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 54.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 55.00000000000001 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 56.00000000000001 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 56.99999999999999 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 57.99999999999999 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 59.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 60.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 61.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 62.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 63.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 64.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 65.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 66.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 67.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 68.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 69.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 70.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 71.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 72.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 73.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 74.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 75.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 76.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 77.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 78.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 79.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 80.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 81.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 82.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 83.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 84.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 85.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 86.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 87.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 88.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 89.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 90.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 91.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 92.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 93.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 94.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 95.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 96.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 97.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 98.0 % finished.
# Current direction TVD of DGM is:  0.49999970165059143
# 99.0 % finished.
# Current direction TVD of DGM is:  0.49999997441959426
# 100.0 % finished.
# All directions average TVD of DGM is:  0.4999998407627836
# Variance TVD of DGM is:  1.370441642787206e-07
# Total time costs:  52.712210178375244 seconds

# %%
1.370441642787206e-07 / 0.4999998407627836
# Out:
# 2.7408841584759396e-07

# %%
M = 100
m = 200
l_i = 2.0

TVD_DGM = 0.0

time_start = time.time()

Max = []
Min = []
Result = []

for count in range(M):
    TVD_temp, Max_temp, Min_temp = tvd(m, l_i)
#     print(Max_temp, Min_temp)
    Max.append(Max_temp)
    Min.append(Min_temp)
    Result.append(TVD_temp)
    print('Current direction TVD of DGM is: ', TVD_temp)
    TVD_DGM = TVD_DGM + TVD_temp
    print((count + 1) / M * 100, '% finished.')

# print('Max of all is: ', np.max(Max))
# print('Min of all is: ', np.min(Min))

TVD_DGM = TVD_DGM / M 
print('All directions average TVD of DGM is: ', TVD_DGM)

print('Variance TVD of DGM is: ', np.sqrt(np.var(Result, ddof = 1)))

time_end = time.time()
print('Total time costs: ', time_end - time_start, 'seconds')
# Out:
# /home/keke/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Current direction TVD of DGM is:  0.49999997446052113
# 1.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 2.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 3.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 4.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 5.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 6.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 7.000000000000001 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 8.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 9.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 10.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 11.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 12.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 13.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 14.000000000000002 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 15.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 16.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 17.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 18.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 19.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 20.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 21.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 22.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 23.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 24.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 25.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 26.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 27.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 28.000000000000004 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 28.999999999999996 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 30.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 31.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 32.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 33.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 34.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 35.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 36.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 37.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 38.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 39.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 40.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 41.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 42.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 43.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 44.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 45.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 46.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 47.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 48.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 49.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 50.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 51.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 52.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 53.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 54.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 55.00000000000001 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 56.00000000000001 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 56.99999999999999 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 57.99999999999999 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 59.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 60.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 61.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 62.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 63.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 64.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 65.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 66.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 67.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 68.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 69.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 70.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 71.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 72.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 73.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 74.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 75.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 76.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 77.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 78.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 79.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 80.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 81.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 82.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 83.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 84.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 85.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 86.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 87.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 88.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 89.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 90.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 91.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 92.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 93.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 94.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 95.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 96.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 97.0 % finished.
# Current direction TVD of DGM is:  0.49999997446052113
# 98.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 99.0 % finished.
# Current direction TVD of DGM is:  0.499999702127944
# 100.0 % finished.
# All directions average TVD of DGM is:  0.49999986008083913
# Variance TVD of DGM is:  1.3508920336291415e-07
# Total time costs:  511.86329555511475 seconds

# %%
1.3508920336291415e-07 / 0.49999986008083913
# Out:
# 2.7017848233212135e-07
