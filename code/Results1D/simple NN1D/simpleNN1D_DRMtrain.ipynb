# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
# import matplotlib.pyplot as plt
from math import *
import time

# %%
torch.cuda.set_device(2)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        output = self.layer_out(x)
        return output

# %%
dimension = 1

# %%
input_width,layer_width = dimension, 1

# %%
net = Net(input_width,layer_width).cuda() # network for u on gpu

# %%
# defination of exact solution
def u_ex(x):     
    u_temp = 2*x**3 - x**2 - x
    return u_temp.reshape([x.size()[0], 1])

# %%
# defination of f(x)
def f(x):
    f_temp = -(12*x - 2)
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp.cuda()

# %%
def model(x):
    x_temp = x.cuda()
    D_x_0 = torch.prod(x_temp, axis = 1).reshape([x.size()[0], 1]) 
    D_x_1 = torch.prod(1.0 - x_temp, axis = 1).reshape([x.size()[0], 1]) 
    model_u_temp = D_x_0 * D_x_1 * net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
initialize_weights(net)

# %%
# loss function to DRM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape).cuda(), create_graph = True)
    grad_u_sq = ((grad_u_hat[0]**2).sum(1)).reshape([len(grad_u_hat[0]), 1])
    part = torch.sum(0.5 * grad_u_sq  - f(x) * u_hat)  / len(x)
    return part

# %%
def relative_l2_error():
    data_size_temp = 500
    x = generate_sample(data_size_temp).cuda() 
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
optimizer = optim.Adam(net.parameters())

# %%
epoch = 10000
data_size = 10000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size).cuda()
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    np.save("unit_DGM_loss_3d.npy", loss_record)
    np.save("unit_DGM_error_3d.npy", error_record)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    if i == epoch - 1:
        # save model parameters
        torch.save(net.state_dict(), 'net_params_DRM.pkl')
        
    loss.backward()
    optimizer.step() 
    torch.cuda.empty_cache() # clear memory
    
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(-0.2066, device='cuda:2')
# current error is:  tensor(0.8644, device='cuda:2')
# current epoch is:  50
# current loss is:  tensor(-0.2570, device='cuda:2')
# current error is:  tensor(0.8277, device='cuda:2')
# current epoch is:  100
# current loss is:  tensor(-0.2950, device='cuda:2')
# current error is:  tensor(0.7898, device='cuda:2')
# current epoch is:  150
# current loss is:  tensor(-0.3323, device='cuda:2')
# current error is:  tensor(0.7575, device='cuda:2')
# current epoch is:  200
# current loss is:  tensor(-0.3800, device='cuda:2')
# current error is:  tensor(0.7215, device='cuda:2')
# current epoch is:  250
# current loss is:  tensor(-0.4006, device='cuda:2')
# current error is:  tensor(0.6885, device='cuda:2')
# current epoch is:  300
# current loss is:  tensor(-0.4496, device='cuda:2')
# current error is:  tensor(0.6554, device='cuda:2')
# current epoch is:  350
# current loss is:  tensor(-0.4757, device='cuda:2')
# current error is:  tensor(0.6231, device='cuda:2')
# current epoch is:  400
# current loss is:  tensor(-0.4991, device='cuda:2')
# current error is:  tensor(0.5922, device='cuda:2')
# current epoch is:  450
# current loss is:  tensor(-0.5287, device='cuda:2')
# current error is:  tensor(0.5617, device='cuda:2')
# current epoch is:  500
# current loss is:  tensor(-0.5524, device='cuda:2')
# current error is:  tensor(0.5319, device='cuda:2')
# current epoch is:  550
# current loss is:  tensor(-0.5758, device='cuda:2')
# current error is:  tensor(0.5030, device='cuda:2')
# current epoch is:  600
# current loss is:  tensor(-0.5926, device='cuda:2')
# current error is:  tensor(0.4752, device='cuda:2')
# current epoch is:  650
# current loss is:  tensor(-0.6117, device='cuda:2')
# current error is:  tensor(0.4482, device='cuda:2')
# current epoch is:  700
# current loss is:  tensor(-0.6211, device='cuda:2')
# current error is:  tensor(0.4220, device='cuda:2')
# current epoch is:  750
# current loss is:  tensor(-0.6432, device='cuda:2')
# current error is:  tensor(0.3966, device='cuda:2')
# current epoch is:  800
# current loss is:  tensor(-0.6525, device='cuda:2')
# current error is:  tensor(0.3724, device='cuda:2')
# current epoch is:  850
# current loss is:  tensor(-0.6739, device='cuda:2')
# current error is:  tensor(0.3483, device='cuda:2')
# current epoch is:  900
# current loss is:  tensor(-0.6668, device='cuda:2')
# current error is:  tensor(0.3263, device='cuda:2')
# current epoch is:  950
# current loss is:  tensor(-0.7100, device='cuda:2')
# current error is:  tensor(0.3041, device='cuda:2')
# current epoch is:  1000
# current loss is:  tensor(-0.6866, device='cuda:2')
# current error is:  tensor(0.2830, device='cuda:2')
# current epoch is:  1050
# current loss is:  tensor(-0.7138, device='cuda:2')
# current error is:  tensor(0.2628, device='cuda:2')
# current epoch is:  1100
# current loss is:  tensor(-0.6875, device='cuda:2')
# current error is:  tensor(0.2442, device='cuda:2')
# current epoch is:  1150
# current loss is:  tensor(-0.7318, device='cuda:2')
# current error is:  tensor(0.2267, device='cuda:2')
# current epoch is:  1200
# current loss is:  tensor(-0.7248, device='cuda:2')
# current error is:  tensor(0.2088, device='cuda:2')
# current epoch is:  1250
# current loss is:  tensor(-0.7332, device='cuda:2')
# current error is:  tensor(0.1923, device='cuda:2')
# current epoch is:  1300
# current loss is:  tensor(-0.7201, device='cuda:2')
# current error is:  tensor(0.1764, device='cuda:2')
# current epoch is:  1350
# current loss is:  tensor(-0.7499, device='cuda:2')
# current error is:  tensor(0.1622, device='cuda:2')
# current epoch is:  1400
# current loss is:  tensor(-0.7178, device='cuda:2')
# current error is:  tensor(0.1483, device='cuda:2')
# current epoch is:  1450
# current loss is:  tensor(-0.7697, device='cuda:2')
# current error is:  tensor(0.1349, device='cuda:2')
# current epoch is:  1500
# current loss is:  tensor(-0.7642, device='cuda:2')
# current error is:  tensor(0.1218, device='cuda:2')
# current epoch is:  1550
# current loss is:  tensor(-0.7446, device='cuda:2')
# current error is:  tensor(0.1109, device='cuda:2')
# current epoch is:  1600
# current loss is:  tensor(-0.7858, device='cuda:2')
# current error is:  tensor(0.1016, device='cuda:2')
# current epoch is:  1650
# current loss is:  tensor(-0.7643, device='cuda:2')
# current error is:  tensor(0.0903, device='cuda:2')
# current epoch is:  1700
# current loss is:  tensor(-0.7972, device='cuda:2')
# current error is:  tensor(0.0820, device='cuda:2')
# current epoch is:  1750
# current loss is:  tensor(-0.7536, device='cuda:2')
# current error is:  tensor(0.0728, device='cuda:2')
# current epoch is:  1800
# current loss is:  tensor(-0.7657, device='cuda:2')
# current error is:  tensor(0.0673, device='cuda:2')
# current epoch is:  1850
# current loss is:  tensor(-0.7534, device='cuda:2')
# current error is:  tensor(0.0595, device='cuda:2')
# current epoch is:  1900
# current loss is:  tensor(-0.7439, device='cuda:2')
# current error is:  tensor(0.0533, device='cuda:2')
# current epoch is:  1950
# current loss is:  tensor(-0.7515, device='cuda:2')
# current error is:  tensor(0.0483, device='cuda:2')
# current epoch is:  2000
# current loss is:  tensor(-0.7721, device='cuda:2')
# current error is:  tensor(0.0425, device='cuda:2')
# current epoch is:  2050
# current loss is:  tensor(-0.7891, device='cuda:2')
# current error is:  tensor(0.0391, device='cuda:2')
# current epoch is:  2100
# current loss is:  tensor(-0.7477, device='cuda:2')
# current error is:  tensor(0.0363, device='cuda:2')
# current epoch is:  2150
# current loss is:  tensor(-0.7602, device='cuda:2')
# current error is:  tensor(0.0317, device='cuda:2')
# current epoch is:  2200
# current loss is:  tensor(-0.7774, device='cuda:2')
# current error is:  tensor(0.0296, device='cuda:2')
# current epoch is:  2250
# current loss is:  tensor(-0.7686, device='cuda:2')
# current error is:  tensor(0.0274, device='cuda:2')
# current epoch is:  2300
# current loss is:  tensor(-0.7613, device='cuda:2')
# current error is:  tensor(0.0258, device='cuda:2')
# current epoch is:  2350
# current loss is:  tensor(-0.7728, device='cuda:2')
# current error is:  tensor(0.0239, device='cuda:2')
# current epoch is:  2400
# current loss is:  tensor(-0.7412, device='cuda:2')
# current error is:  tensor(0.0229, device='cuda:2')
# current epoch is:  2450
# current loss is:  tensor(-0.7648, device='cuda:2')
# current error is:  tensor(0.0222, device='cuda:2')
# current epoch is:  2500
# current loss is:  tensor(-0.7875, device='cuda:2')
# current error is:  tensor(0.0214, device='cuda:2')
# current epoch is:  2550
# current loss is:  tensor(-0.7680, device='cuda:2')
# current error is:  tensor(0.0208, device='cuda:2')
# current epoch is:  2600
# current loss is:  tensor(-0.7504, device='cuda:2')
# current error is:  tensor(0.0196, device='cuda:2')
# current epoch is:  2650
# current loss is:  tensor(-0.7627, device='cuda:2')
# current error is:  tensor(0.0197, device='cuda:2')
# current epoch is:  2700
# current loss is:  tensor(-0.7766, device='cuda:2')
# current error is:  tensor(0.0204, device='cuda:2')
# current epoch is:  2750
# current loss is:  tensor(-0.7737, device='cuda:2')
# current error is:  tensor(0.0188, device='cuda:2')
# current epoch is:  2800
# current loss is:  tensor(-0.7609, device='cuda:2')
# current error is:  tensor(0.0196, device='cuda:2')
# current epoch is:  2850
# current loss is:  tensor(-0.7633, device='cuda:2')
# current error is:  tensor(0.0195, device='cuda:2')
# current epoch is:  2900
# current loss is:  tensor(-0.7533, device='cuda:2')
# current error is:  tensor(0.0190, device='cuda:2')
# current epoch is:  2950
# current loss is:  tensor(-0.7606, device='cuda:2')
# current error is:  tensor(0.0171, device='cuda:2')
# current epoch is:  3000
# current loss is:  tensor(-0.8084, device='cuda:2')
# current error is:  tensor(0.0178, device='cuda:2')
# current epoch is:  3050
# current loss is:  tensor(-0.7815, device='cuda:2')
# current error is:  tensor(0.0170, device='cuda:2')
# current epoch is:  3100
# current loss is:  tensor(-0.8024, device='cuda:2')
# current error is:  tensor(0.0177, device='cuda:2')
# current epoch is:  3150
# current loss is:  tensor(-0.7449, device='cuda:2')
# current error is:  tensor(0.0171, device='cuda:2')
# current epoch is:  3200
# current loss is:  tensor(-0.7635, device='cuda:2')
# current error is:  tensor(0.0166, device='cuda:2')
# current epoch is:  3250
# current loss is:  tensor(-0.7692, device='cuda:2')
# current error is:  tensor(0.0159, device='cuda:2')
# current epoch is:  3300
# current loss is:  tensor(-0.7605, device='cuda:2')
# current error is:  tensor(0.0156, device='cuda:2')
# current epoch is:  3350
# current loss is:  tensor(-0.7698, device='cuda:2')
# current error is:  tensor(0.0152, device='cuda:2')
# current epoch is:  3400
# current loss is:  tensor(-0.7443, device='cuda:2')
# current error is:  tensor(0.0149, device='cuda:2')
# current epoch is:  3450
# current loss is:  tensor(-0.7458, device='cuda:2')
# current error is:  tensor(0.0145, device='cuda:2')
# current epoch is:  3500
# current loss is:  tensor(-0.7706, device='cuda:2')
# current error is:  tensor(0.0142, device='cuda:2')
# current epoch is:  3550
# current loss is:  tensor(-0.7891, device='cuda:2')
# current error is:  tensor(0.0135, device='cuda:2')
# current epoch is:  3600
# current loss is:  tensor(-0.7438, device='cuda:2')
# current error is:  tensor(0.0129, device='cuda:2')
# current epoch is:  3650
# current loss is:  tensor(-0.7706, device='cuda:2')
# current error is:  tensor(0.0124, device='cuda:2')
# current epoch is:  3700
# current loss is:  tensor(-0.7754, device='cuda:2')
# current error is:  tensor(0.0116, device='cuda:2')
# current epoch is:  3750
# current loss is:  tensor(-0.7448, device='cuda:2')
# current error is:  tensor(0.0119, device='cuda:2')
# current epoch is:  3800
# current loss is:  tensor(-0.7811, device='cuda:2')
# current error is:  tensor(0.0116, device='cuda:2')
# current epoch is:  3850
# current loss is:  tensor(-0.7403, device='cuda:2')
# current error is:  tensor(0.0106, device='cuda:2')
# current epoch is:  3900
# current loss is:  tensor(-0.7543, device='cuda:2')
# current error is:  tensor(0.0109, device='cuda:2')
# current epoch is:  3950
# current loss is:  tensor(-0.7728, device='cuda:2')
# current error is:  tensor(0.0100, device='cuda:2')
# current epoch is:  4000
# current loss is:  tensor(-0.7795, device='cuda:2')
# current error is:  tensor(0.0099, device='cuda:2')
# current epoch is:  4050
# current loss is:  tensor(-0.7531, device='cuda:2')
# current error is:  tensor(0.0095, device='cuda:2')
# current epoch is:  4100
# current loss is:  tensor(-0.7509, device='cuda:2')
# current error is:  tensor(0.0095, device='cuda:2')
# current epoch is:  4150
# current loss is:  tensor(-0.7690, device='cuda:2')
# current error is:  tensor(0.0084, device='cuda:2')
# current epoch is:  4200
# current loss is:  tensor(-0.7437, device='cuda:2')
# current error is:  tensor(0.0085, device='cuda:2')
# current epoch is:  4250
# current loss is:  tensor(-0.7692, device='cuda:2')
# current error is:  tensor(0.0085, device='cuda:2')
# current epoch is:  4300
# current loss is:  tensor(-0.7269, device='cuda:2')
# current error is:  tensor(0.0083, device='cuda:2')
# current epoch is:  4350
# current loss is:  tensor(-0.7820, device='cuda:2')
# current error is:  tensor(0.0074, device='cuda:2')
# current epoch is:  4400
# current loss is:  tensor(-0.8053, device='cuda:2')
# current error is:  tensor(0.0070, device='cuda:2')
# current epoch is:  4450
# current loss is:  tensor(-0.7657, device='cuda:2')
# current error is:  tensor(0.0067, device='cuda:2')
# current epoch is:  4500
# current loss is:  tensor(-0.7464, device='cuda:2')
# current error is:  tensor(0.0066, device='cuda:2')
# current epoch is:  4550
# current loss is:  tensor(-0.7578, device='cuda:2')
# current error is:  tensor(0.0060, device='cuda:2')
# current epoch is:  4600
# current loss is:  tensor(-0.7594, device='cuda:2')
# current error is:  tensor(0.0063, device='cuda:2')
# current epoch is:  4650
# current loss is:  tensor(-0.7807, device='cuda:2')
# current error is:  tensor(0.0058, device='cuda:2')
# current epoch is:  4700
# current loss is:  tensor(-0.7862, device='cuda:2')
# current error is:  tensor(0.0060, device='cuda:2')
# current epoch is:  4750
# current loss is:  tensor(-0.7834, device='cuda:2')
# current error is:  tensor(0.0054, device='cuda:2')
# current epoch is:  4800
# current loss is:  tensor(-0.7942, device='cuda:2')
# current error is:  tensor(0.0051, device='cuda:2')
# current epoch is:  4850
# current loss is:  tensor(-0.7398, device='cuda:2')
# current error is:  tensor(0.0050, device='cuda:2')
# current epoch is:  4900
# current loss is:  tensor(-0.7865, device='cuda:2')
# current error is:  tensor(0.0041, device='cuda:2')
# current epoch is:  4950
# current loss is:  tensor(-0.7541, device='cuda:2')
# current error is:  tensor(0.0044, device='cuda:2')
# current epoch is:  5000
# current loss is:  tensor(-0.7651, device='cuda:2')
# current error is:  tensor(0.0041, device='cuda:2')
# current epoch is:  5050
# current loss is:  tensor(-0.7550, device='cuda:2')
# current error is:  tensor(0.0036, device='cuda:2')
# current epoch is:  5100
# current loss is:  tensor(-0.7502, device='cuda:2')
# current error is:  tensor(0.0037, device='cuda:2')
# current epoch is:  5150
# current loss is:  tensor(-0.7988, device='cuda:2')
# current error is:  tensor(0.0036, device='cuda:2')
# current epoch is:  5200
# current loss is:  tensor(-0.8192, device='cuda:2')
# current error is:  tensor(0.0038, device='cuda:2')
# current epoch is:  5250
# current loss is:  tensor(-0.7835, device='cuda:2')
# current error is:  tensor(0.0032, device='cuda:2')
# current epoch is:  5300
# current loss is:  tensor(-0.7812, device='cuda:2')
# current error is:  tensor(0.0025, device='cuda:2')
# current epoch is:  5350
# current loss is:  tensor(-0.7731, device='cuda:2')
# current error is:  tensor(0.0022, device='cuda:2')
# current epoch is:  5400
# current loss is:  tensor(-0.7911, device='cuda:2')
# current error is:  tensor(0.0024, device='cuda:2')
# current epoch is:  5450
# current loss is:  tensor(-0.7556, device='cuda:2')
# current error is:  tensor(0.0020, device='cuda:2')
# current epoch is:  5500
# current loss is:  tensor(-0.7438, device='cuda:2')
# current error is:  tensor(0.0017, device='cuda:2')
# current epoch is:  5550
# current loss is:  tensor(-0.7616, device='cuda:2')
# current error is:  tensor(0.0026, device='cuda:2')
# current epoch is:  5600
# current loss is:  tensor(-0.7685, device='cuda:2')
# current error is:  tensor(0.0034, device='cuda:2')
# current epoch is:  5650
# current loss is:  tensor(-0.7928, device='cuda:2')
# current error is:  tensor(0.0018, device='cuda:2')
# current epoch is:  5700
# current loss is:  tensor(-0.7682, device='cuda:2')
# current error is:  tensor(0.0022, device='cuda:2')
# current epoch is:  5750
# current loss is:  tensor(-0.7649, device='cuda:2')
# current error is:  tensor(0.0011, device='cuda:2')
# current epoch is:  5800
# current loss is:  tensor(-0.7581, device='cuda:2')
# current error is:  tensor(0.0010, device='cuda:2')
# current epoch is:  5850
# current loss is:  tensor(-0.7728, device='cuda:2')
# current error is:  tensor(0.0017, device='cuda:2')
# current epoch is:  5900
# current loss is:  tensor(-0.7711, device='cuda:2')
# current error is:  tensor(0.0028, device='cuda:2')
# current epoch is:  5950
# current loss is:  tensor(-0.7701, device='cuda:2')
# current error is:  tensor(0.0037, device='cuda:2')
# current epoch is:  6000
# current loss is:  tensor(-0.7486, device='cuda:2')
# current error is:  tensor(0.0017, device='cuda:2')
# current epoch is:  6050
# current loss is:  tensor(-0.7487, device='cuda:2')
# current error is:  tensor(0.0008, device='cuda:2')
# current epoch is:  6100
# current loss is:  tensor(-0.7590, device='cuda:2')
# current error is:  tensor(0.0028, device='cuda:2')
# current epoch is:  6150
# current loss is:  tensor(-0.8099, device='cuda:2')
# current error is:  tensor(0.0046, device='cuda:2')
# current epoch is:  6200
# current loss is:  tensor(-0.7869, device='cuda:2')
# current error is:  tensor(0.0020, device='cuda:2')
# current epoch is:  6250
# current loss is:  tensor(-0.7794, device='cuda:2')
# current error is:  tensor(0.0008, device='cuda:2')
# current epoch is:  6300
# current loss is:  tensor(-0.7617, device='cuda:2')
# current error is:  tensor(0.0018, device='cuda:2')
# current epoch is:  6350
# current loss is:  tensor(-0.7895, device='cuda:2')
# current error is:  tensor(0.0010, device='cuda:2')
# current epoch is:  6400
# current loss is:  tensor(-0.7658, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  6450
# current loss is:  tensor(-0.7872, device='cuda:2')
# current error is:  tensor(0.0004, device='cuda:2')
# current epoch is:  6500
# current loss is:  tensor(-0.7861, device='cuda:2')
# current error is:  tensor(0.0004, device='cuda:2')
# current epoch is:  6550
# current loss is:  tensor(-0.7824, device='cuda:2')
# current error is:  tensor(0.0006, device='cuda:2')
# current epoch is:  6600
# current loss is:  tensor(-0.7982, device='cuda:2')
# current error is:  tensor(0.0008, device='cuda:2')
# current epoch is:  6650
# current loss is:  tensor(-0.7747, device='cuda:2')
# current error is:  tensor(0.0013, device='cuda:2')
# current epoch is:  6700
# current loss is:  tensor(-0.7935, device='cuda:2')
# current error is:  tensor(0.0020, device='cuda:2')
# current epoch is:  6750
# current loss is:  tensor(-0.7693, device='cuda:2')
# current error is:  tensor(0.0030, device='cuda:2')
# current epoch is:  6800
# current loss is:  tensor(-0.7538, device='cuda:2')
# current error is:  tensor(0.0010, device='cuda:2')
# current epoch is:  6850
# current loss is:  tensor(-0.7782, device='cuda:2')
# current error is:  tensor(0.0004, device='cuda:2')
# current epoch is:  6900
# current loss is:  tensor(-0.8014, device='cuda:2')
# current error is:  tensor(0.0013, device='cuda:2')
# current epoch is:  6950
# current loss is:  tensor(-0.7585, device='cuda:2')
# current error is:  tensor(0.0013, device='cuda:2')
# current epoch is:  7000
# current loss is:  tensor(-0.7980, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  7050
# current loss is:  tensor(-0.7794, device='cuda:2')
# current error is:  tensor(0.0005, device='cuda:2')
# current epoch is:  7100
# current loss is:  tensor(-0.7647, device='cuda:2')
# current error is:  tensor(0.0032, device='cuda:2')
# current epoch is:  7150
# current loss is:  tensor(-0.7514, device='cuda:2')
# current error is:  tensor(0.0022, device='cuda:2')
# current epoch is:  7200
# current loss is:  tensor(-0.7531, device='cuda:2')
# current error is:  tensor(0.0003, device='cuda:2')
# current epoch is:  7250
# current loss is:  tensor(-0.7664, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  7300
# current loss is:  tensor(-0.7605, device='cuda:2')
# current error is:  tensor(0.0002, device='cuda:2')
# current epoch is:  7350
# current loss is:  tensor(-0.7871, device='cuda:2')
# current error is:  tensor(0.0021, device='cuda:2')
# current epoch is:  7400
# current loss is:  tensor(-0.7441, device='cuda:2')
# current error is:  tensor(0.0040, device='cuda:2')
# current epoch is:  7450
# current loss is:  tensor(-0.7677, device='cuda:2')
# current error is:  tensor(0.0014, device='cuda:2')
# current epoch is:  7500
# current loss is:  tensor(-0.7521, device='cuda:2')
# current error is:  tensor(0.0023, device='cuda:2')
# current epoch is:  7550
# current loss is:  tensor(-0.7523, device='cuda:2')
# current error is:  tensor(0.0003, device='cuda:2')
# current epoch is:  7600
# current loss is:  tensor(-0.7467, device='cuda:2')
# current error is:  tensor(0.0024, device='cuda:2')
# current epoch is:  7650
# current loss is:  tensor(-0.7482, device='cuda:2')
# current error is:  tensor(0.0009, device='cuda:2')
# current epoch is:  7700
# current loss is:  tensor(-0.7470, device='cuda:2')
# current error is:  tensor(0.0006, device='cuda:2')
# current epoch is:  7750
# current loss is:  tensor(-0.7517, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  7800
# current loss is:  tensor(-0.7521, device='cuda:2')
# current error is:  tensor(0.0002, device='cuda:2')
# current epoch is:  7850
# current loss is:  tensor(-0.7550, device='cuda:2')
# current error is:  tensor(0.0021, device='cuda:2')
# current epoch is:  7900
# current loss is:  tensor(-0.7845, device='cuda:2')
# current error is:  tensor(0.0003, device='cuda:2')
# current epoch is:  7950
# current loss is:  tensor(-0.7652, device='cuda:2')
# current error is:  tensor(0.0011, device='cuda:2')
# current epoch is:  8000
# current loss is:  tensor(-0.7639, device='cuda:2')
# current error is:  tensor(0.0008, device='cuda:2')
# current epoch is:  8050
# current loss is:  tensor(-0.7500, device='cuda:2')
# current error is:  tensor(0.0025, device='cuda:2')
# current epoch is:  8100
# current loss is:  tensor(-0.7664, device='cuda:2')
# current error is:  tensor(0.0024, device='cuda:2')
# current epoch is:  8150
# current loss is:  tensor(-0.7698, device='cuda:2')
# current error is:  tensor(0.0017, device='cuda:2')
# current epoch is:  8200
# current loss is:  tensor(-0.7580, device='cuda:2')
# current error is:  tensor(0.0014, device='cuda:2')
# current epoch is:  8250
# current loss is:  tensor(-0.7791, device='cuda:2')
# current error is:  tensor(0.0011, device='cuda:2')
# current epoch is:  8300
# current loss is:  tensor(-0.7715, device='cuda:2')
# current error is:  tensor(0.0025, device='cuda:2')
# current epoch is:  8350
# current loss is:  tensor(-0.7766, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  8400
# current loss is:  tensor(-0.7601, device='cuda:2')
# current error is:  tensor(0.0039, device='cuda:2')
# current epoch is:  8450
# current loss is:  tensor(-0.7594, device='cuda:2')
# current error is:  tensor(0.0014, device='cuda:2')
# current epoch is:  8500
# current loss is:  tensor(-0.7727, device='cuda:2')
# current error is:  tensor(0.0012, device='cuda:2')
# current epoch is:  8550
# current loss is:  tensor(-0.7385, device='cuda:2')
# current error is:  tensor(0.0011, device='cuda:2')
# current epoch is:  8600
# current loss is:  tensor(-0.7471, device='cuda:2')
# current error is:  tensor(0.0020, device='cuda:2')
# current epoch is:  8650
# current loss is:  tensor(-0.7565, device='cuda:2')
# current error is:  tensor(0.0013, device='cuda:2')
# current epoch is:  8700
# current loss is:  tensor(-0.7700, device='cuda:2')
# current error is:  tensor(0.0044, device='cuda:2')
# current epoch is:  8750
# current loss is:  tensor(-0.7611, device='cuda:2')
# current error is:  tensor(0.0015, device='cuda:2')
# current epoch is:  8800
# current loss is:  tensor(-0.7731, device='cuda:2')
# current error is:  tensor(0.0037, device='cuda:2')
# current epoch is:  8850
# current loss is:  tensor(-0.7853, device='cuda:2')
# current error is:  tensor(0.0037, device='cuda:2')
# current epoch is:  8900
# current loss is:  tensor(-0.7455, device='cuda:2')
# current error is:  tensor(0.0005, device='cuda:2')
# current epoch is:  8950
# current loss is:  tensor(-0.7440, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  9000
# current loss is:  tensor(-0.7435, device='cuda:2')
# current error is:  tensor(0.0022, device='cuda:2')
# current epoch is:  9050
# current loss is:  tensor(-0.7823, device='cuda:2')
# current error is:  tensor(0.0018, device='cuda:2')
# current epoch is:  9100
# current loss is:  tensor(-0.7788, device='cuda:2')
# current error is:  tensor(0.0039, device='cuda:2')
# current epoch is:  9150
# current loss is:  tensor(-0.7206, device='cuda:2')
# current error is:  tensor(0.0003, device='cuda:2')
# current epoch is:  9200
# current loss is:  tensor(-0.7590, device='cuda:2')
# current error is:  tensor(0.0034, device='cuda:2')
# current epoch is:  9250
# current loss is:  tensor(-0.7707, device='cuda:2')
# current error is:  tensor(0.0004, device='cuda:2')
# current epoch is:  9300
# current loss is:  tensor(-0.7857, device='cuda:2')
# current error is:  tensor(0.0008, device='cuda:2')
# current epoch is:  9350
# current loss is:  tensor(-0.7671, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  9400
# current loss is:  tensor(-0.7769, device='cuda:2')
# current error is:  tensor(0.0036, device='cuda:2')
# current epoch is:  9450
# current loss is:  tensor(-0.7826, device='cuda:2')
# current error is:  tensor(0.0022, device='cuda:2')
# current epoch is:  9500
# current loss is:  tensor(-0.7608, device='cuda:2')
# current error is:  tensor(0.0014, device='cuda:2')
# current epoch is:  9550
# current loss is:  tensor(-0.7819, device='cuda:2')
# current error is:  tensor(0.0016, device='cuda:2')
# current epoch is:  9600
# current loss is:  tensor(-0.7851, device='cuda:2')
# current error is:  tensor(0.0001, device='cuda:2')
# current epoch is:  9650
# current loss is:  tensor(-0.7733, device='cuda:2')
# current error is:  tensor(0.0013, device='cuda:2')
# current epoch is:  9700
# current loss is:  tensor(-0.7728, device='cuda:2')
# current error is:  tensor(0.0020, device='cuda:2')
# current epoch is:  9750
# current loss is:  tensor(-0.7719, device='cuda:2')
# current error is:  tensor(0.0043, device='cuda:2')
# current epoch is:  9800
# current loss is:  tensor(-0.7539, device='cuda:2')
# current error is:  tensor(0.0037, device='cuda:2')
# current epoch is:  9850
# current loss is:  tensor(-0.7450, device='cuda:2')
# current error is:  tensor(0.0007, device='cuda:2')
# current epoch is:  9900
# current loss is:  tensor(-0.7624, device='cuda:2')
# current error is:  tensor(0.0006, device='cuda:2')
# current epoch is:  9950
# current loss is:  tensor(-0.7515, device='cuda:2')
# current error is:  tensor(0.0032, device='cuda:2')
# total time is:  80.49766278266907 seconds

# %%
param = {}
for name,parameters in net.named_parameters():
    print(name,':',parameters.size())
    print(parameters)
# Out:
# layer_out.weight : torch.Size([1, 1])
# Parameter containing:
# tensor([[-1.9974]], device='cuda:2', requires_grad=True)
# layer_out.bias : torch.Size([1])
# Parameter containing:
# tensor([-0.9977], device='cuda:2', requires_grad=True)
