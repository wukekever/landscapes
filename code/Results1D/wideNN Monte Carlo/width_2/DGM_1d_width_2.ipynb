# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
from math import *
import time

# %%
torch.cuda.set_device(1)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build neural network
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        self.layer1 = torch.nn.Linear(layer_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        y = self.layer_in(x)
        y = activation(self.layer2(activation(self.layer1(y)))) 
        output = self.layer_out(y)
        return output

# %%
dimension = 1

# %%
input_width,layer_width = dimension, 2

# %%
net = Net(input_width,layer_width).cuda() # network for u on gpu

# %%
# defination of exact solution
def u_ex(x):     
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    return u_temp.reshape([x.size()[0], 1])

# %%
# defination of f(x)
def f(x):
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    f_temp = dimension * pi**2 * u_temp 
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp.cuda()

# %%
def model(x):
    x_temp = x.cuda()
    D_x_0 = torch.prod(x_temp, axis = 1).reshape([x.size()[0], 1]) 
    D_x_1 = torch.prod(1.0 - x_temp, axis = 1).reshape([x.size()[0], 1]) 
    model_u_temp = D_x_0 * D_x_1 * net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
initialize_weights(net)

# %%
# loss function to DGM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape).cuda(), create_graph = True)
    laplace_u = torch.zeros([len(grad_u_hat[0]), 1]).cuda()
    for index in range(dimension):
        p_temp = grad_u_hat[0][:, index].reshape([len(grad_u_hat[0]), 1])
        temp = torch.autograd.grad(outputs = p_temp, inputs = x, grad_outputs = torch.ones(p_temp.shape).cuda(), create_graph = True, allow_unused = True)[0]
        laplace_u = temp[:, index].reshape([len(grad_u_hat[0]), 1]) + laplace_u
        part_2 = torch.sum((-laplace_u - f(x))**2)  / len(x)
    return part_2

# %%
def relative_l2_error():
    data_size_temp = 200
    x = generate_sample(data_size_temp).cuda() 
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
optimizer = optim.Adam(net.parameters())

# %%
epoch = 5000
data_size = 1000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size).cuda()
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    np.save("unit_DGM_loss_1d.npy", loss_record)
    np.save("unit_DGM_error_1d.npy", error_record)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    if i == epoch - 1:
        # save model parameters
        torch.save(net.state_dict(), 'net_params_DGM.pkl')
        
    loss.backward()
    optimizer.step() 
    torch.cuda.empty_cache() # clear memory
    
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(47.7712, device='cuda:1')
# current error is:  tensor(0.9976, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(45.0141, device='cuda:1')
# current error is:  tensor(0.9466, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(35.9456, device='cuda:1')
# current error is:  tensor(0.8712, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(29.9423, device='cuda:1')
# current error is:  tensor(0.7667, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(20.9978, device='cuda:1')
# current error is:  tensor(0.6333, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(15.4687, device='cuda:1')
# current error is:  tensor(0.4822, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(12.0477, device='cuda:1')
# current error is:  tensor(0.3653, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(10.4169, device='cuda:1')
# current error is:  tensor(0.2888, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(10.0157, device='cuda:1')
# current error is:  tensor(0.2548, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(9.3874, device='cuda:1')
# current error is:  tensor(0.2365, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(9.5414, device='cuda:1')
# current error is:  tensor(0.2278, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(8.8226, device='cuda:1')
# current error is:  tensor(0.2179, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(9.0622, device='cuda:1')
# current error is:  tensor(0.2155, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(9.5932, device='cuda:1')
# current error is:  tensor(0.2049, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(9.5637, device='cuda:1')
# current error is:  tensor(0.2029, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(8.9264, device='cuda:1')
# current error is:  tensor(0.2002, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(8.8485, device='cuda:1')
# current error is:  tensor(0.1964, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(8.4605, device='cuda:1')
# current error is:  tensor(0.1891, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(8.8267, device='cuda:1')
# current error is:  tensor(0.1876, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(8.2366, device='cuda:1')
# current error is:  tensor(0.1912, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(7.5861, device='cuda:1')
# current error is:  tensor(0.1845, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(6.8165, device='cuda:1')
# current error is:  tensor(0.1763, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(5.4949, device='cuda:1')
# current error is:  tensor(0.1654, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(4.0065, device='cuda:1')
# current error is:  tensor(0.1397, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(2.8753, device='cuda:1')
# current error is:  tensor(0.1154, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(1.7793, device='cuda:1')
# current error is:  tensor(0.0854, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(1.3858, device='cuda:1')
# current error is:  tensor(0.0609, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(1.0276, device='cuda:1')
# current error is:  tensor(0.0475, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(1.0037, device='cuda:1')
# current error is:  tensor(0.0378, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(0.7024, device='cuda:1')
# current error is:  tensor(0.0318, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(0.6519, device='cuda:1')
# current error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(0.5802, device='cuda:1')
# current error is:  tensor(0.0246, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(0.5313, device='cuda:1')
# current error is:  tensor(0.0209, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(0.4022, device='cuda:1')
# current error is:  tensor(0.0196, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(0.3517, device='cuda:1')
# current error is:  tensor(0.0182, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(0.3277, device='cuda:1')
# current error is:  tensor(0.0170, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(0.2934, device='cuda:1')
# current error is:  tensor(0.0156, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(0.2680, device='cuda:1')
# current error is:  tensor(0.0126, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(0.2408, device='cuda:1')
# current error is:  tensor(0.0128, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(0.2295, device='cuda:1')
# current error is:  tensor(0.0123, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(0.2136, device='cuda:1')
# current error is:  tensor(0.0107, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(0.1855, device='cuda:1')
# current error is:  tensor(0.0105, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(0.1726, device='cuda:1')
# current error is:  tensor(0.0103, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(0.1537, device='cuda:1')
# current error is:  tensor(0.0090, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(0.1462, device='cuda:1')
# current error is:  tensor(0.0087, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(0.1327, device='cuda:1')
# current error is:  tensor(0.0086, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(0.1131, device='cuda:1')
# current error is:  tensor(0.0077, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(0.1030, device='cuda:1')
# current error is:  tensor(0.0075, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(0.1044, device='cuda:1')
# current error is:  tensor(0.0072, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(0.0917, device='cuda:1')
# current error is:  tensor(0.0071, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(0.0866, device='cuda:1')
# current error is:  tensor(0.0062, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(0.0676, device='cuda:1')
# current error is:  tensor(0.0054, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(0.0648, device='cuda:1')
# current error is:  tensor(0.0052, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(0.0590, device='cuda:1')
# current error is:  tensor(0.0053, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(0.0540, device='cuda:1')
# current error is:  tensor(0.0049, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(0.0492, device='cuda:1')
# current error is:  tensor(0.0044, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(0.0441, device='cuda:1')
# current error is:  tensor(0.0042, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(0.0372, device='cuda:1')
# current error is:  tensor(0.0042, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(0.0341, device='cuda:1')
# current error is:  tensor(0.0035, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(0.0319, device='cuda:1')
# current error is:  tensor(0.0032, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(0.0262, device='cuda:1')
# current error is:  tensor(0.0030, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(0.0207, device='cuda:1')
# current error is:  tensor(0.0025, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(0.0202, device='cuda:1')
# current error is:  tensor(0.0025, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(0.0160, device='cuda:1')
# current error is:  tensor(0.0022, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(0.0152, device='cuda:1')
# current error is:  tensor(0.0021, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(0.0130, device='cuda:1')
# current error is:  tensor(0.0020, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(0.0108, device='cuda:1')
# current error is:  tensor(0.0017, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(0.0100, device='cuda:1')
# current error is:  tensor(0.0015, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(0.0087, device='cuda:1')
# current error is:  tensor(0.0014, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(0.0071, device='cuda:1')
# current error is:  tensor(0.0012, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(0.0056, device='cuda:1')
# current error is:  tensor(0.0013, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(0.0055, device='cuda:1')
# current error is:  tensor(0.0010, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(0.0055, device='cuda:1')
# current error is:  tensor(0.0010, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(0.0051, device='cuda:1')
# current error is:  tensor(0.0010, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(0.0045, device='cuda:1')
# current error is:  tensor(0.0008, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(0.0044, device='cuda:1')
# current error is:  tensor(0.0008, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(0.0044, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(0.0040, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(0.0038, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(0.0042, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(0.0043, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(0.0038, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(0.0032, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(0.0037, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(0.0040, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(0.0036, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(0.0039, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(0.0037, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(0.0034, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(0.0032, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(0.0035, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(0.0036, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(0.0032, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(0.0032, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(0.0034, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(0.0034, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(0.0031, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(0.0031, device='cuda:1')
# current error is:  tensor(0.0005, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(0.0033, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(0.0031, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# total time is:  123.40622186660767 seconds

# %%
np.save("unit_DGM_loss_1d.npy", loss_record)
np.save("unit_DGM_error_1d.npy", error_record)
