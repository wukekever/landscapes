# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
from math import *
import time

# %%
torch.cuda.set_device(1)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build neural network
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        self.layer1 = torch.nn.Linear(layer_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        y = self.layer_in(x)
        y = activation(self.layer2(activation(self.layer1(y)))) 
        output = self.layer_out(y)
        return output

# %%
dimension = 1

# %%
input_width,layer_width = dimension, 2

# %%
net = Net(input_width,layer_width).cuda() # network for u on gpu

# %%
# defination of exact solution
def u_ex(x):     
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    return u_temp.reshape([x.size()[0], 1])

# %%
# defination of f(x)
def f(x):
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    f_temp = dimension * pi**2 * u_temp 
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp.cuda()

# %%
def model(x):
    x_temp = x.cuda()
    D_x_0 = torch.prod(x_temp, axis = 1).reshape([x.size()[0], 1]) 
    D_x_1 = torch.prod(1.0 - x_temp, axis = 1).reshape([x.size()[0], 1]) 
    model_u_temp = D_x_0 * D_x_1 * net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
initialize_weights(net)

# %%
# loss function to DRM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape).cuda(), create_graph = True)
    grad_u_sq = ((grad_u_hat[0]**2).sum(1)).reshape([len(grad_u_hat[0]), 1])
    part = torch.sum(0.5 * grad_u_sq  - f(x) * u_hat)  / len(x)
    return part

# %%
def relative_l2_error():
    data_size_temp = 200
    x = generate_sample(data_size_temp).cuda() 
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
optimizer = optim.Adam(net.parameters())

# %%
epoch = 5000
data_size = 1000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size).cuda()
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    np.save("unit_DRM_loss_1d.npy", loss_record)
    np.save("unit_DRM_error_1d.npy", error_record)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    if i == epoch - 1:
        # save model parameters
        torch.save(net.state_dict(), 'net_params_DRM.pkl')
        
    loss.backward()
    optimizer.step() 
    torch.cuda.empty_cache() # clear memory
    
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(-0.1791, device='cuda:1')
# current error is:  tensor(0.9608, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(-0.4408, device='cuda:1')
# current error is:  tensor(0.9047, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(-0.7381, device='cuda:1')
# current error is:  tensor(0.8348, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(-1.0469, device='cuda:1')
# current error is:  tensor(0.7316, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(-1.6353, device='cuda:1')
# current error is:  tensor(0.5893, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(-1.9317, device='cuda:1')
# current error is:  tensor(0.4026, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(-2.2492, device='cuda:1')
# current error is:  tensor(0.2164, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(-2.3622, device='cuda:1')
# current error is:  tensor(0.1544, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(-2.2191, device='cuda:1')
# current error is:  tensor(0.1203, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(-2.5156, device='cuda:1')
# current error is:  tensor(0.1162, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(-2.2467, device='cuda:1')
# current error is:  tensor(0.1020, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(-2.2254, device='cuda:1')
# current error is:  tensor(0.0933, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(-2.4075, device='cuda:1')
# current error is:  tensor(0.0934, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(-2.2549, device='cuda:1')
# current error is:  tensor(0.0817, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(-2.2661, device='cuda:1')
# current error is:  tensor(0.0814, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(-1.8785, device='cuda:1')
# current error is:  tensor(0.0723, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(-2.0778, device='cuda:1')
# current error is:  tensor(0.0670, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(-2.7661, device='cuda:1')
# current error is:  tensor(0.0684, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(-2.2025, device='cuda:1')
# current error is:  tensor(0.0599, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(-2.5842, device='cuda:1')
# current error is:  tensor(0.0647, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-2.1041, device='cuda:1')
# current error is:  tensor(0.0556, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-2.5707, device='cuda:1')
# current error is:  tensor(0.0491, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-2.6222, device='cuda:1')
# current error is:  tensor(0.0461, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-2.4730, device='cuda:1')
# current error is:  tensor(0.0479, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-2.4143, device='cuda:1')
# current error is:  tensor(0.0425, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-2.2692, device='cuda:1')
# current error is:  tensor(0.0549, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-2.6055, device='cuda:1')
# current error is:  tensor(0.0418, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-2.4539, device='cuda:1')
# current error is:  tensor(0.0436, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-2.4323, device='cuda:1')
# current error is:  tensor(0.0442, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-2.4522, device='cuda:1')
# current error is:  tensor(0.0411, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-2.5056, device='cuda:1')
# current error is:  tensor(0.0403, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-2.3453, device='cuda:1')
# current error is:  tensor(0.0418, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-2.3039, device='cuda:1')
# current error is:  tensor(0.0384, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-2.6767, device='cuda:1')
# current error is:  tensor(0.0366, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-2.5064, device='cuda:1')
# current error is:  tensor(0.0326, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-2.4736, device='cuda:1')
# current error is:  tensor(0.0408, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-2.4736, device='cuda:1')
# current error is:  tensor(0.0343, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-2.5023, device='cuda:1')
# current error is:  tensor(0.0358, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-2.2633, device='cuda:1')
# current error is:  tensor(0.0384, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-2.7630, device='cuda:1')
# current error is:  tensor(0.0315, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-2.3291, device='cuda:1')
# current error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-2.2451, device='cuda:1')
# current error is:  tensor(0.0287, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-2.5646, device='cuda:1')
# current error is:  tensor(0.0273, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-2.4450, device='cuda:1')
# current error is:  tensor(0.0279, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-2.3083, device='cuda:1')
# current error is:  tensor(0.0247, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-2.3691, device='cuda:1')
# current error is:  tensor(0.0241, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-2.1125, device='cuda:1')
# current error is:  tensor(0.0286, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-2.3387, device='cuda:1')
# current error is:  tensor(0.0253, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-2.6529, device='cuda:1')
# current error is:  tensor(0.0281, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-2.3745, device='cuda:1')
# current error is:  tensor(0.0204, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-2.4198, device='cuda:1')
# current error is:  tensor(0.0226, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-2.8129, device='cuda:1')
# current error is:  tensor(0.0207, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-2.6247, device='cuda:1')
# current error is:  tensor(0.0163, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-2.3843, device='cuda:1')
# current error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-2.4408, device='cuda:1')
# current error is:  tensor(0.0168, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-2.5901, device='cuda:1')
# current error is:  tensor(0.0146, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-2.5080, device='cuda:1')
# current error is:  tensor(0.0142, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-2.7276, device='cuda:1')
# current error is:  tensor(0.0132, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-2.7083, device='cuda:1')
# current error is:  tensor(0.0174, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-2.5833, device='cuda:1')
# current error is:  tensor(0.0153, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-2.3743, device='cuda:1')
# current error is:  tensor(0.0183, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-2.6365, device='cuda:1')
# current error is:  tensor(0.0119, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-2.5028, device='cuda:1')
# current error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-2.2499, device='cuda:1')
# current error is:  tensor(0.0163, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-2.5099, device='cuda:1')
# current error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-2.4522, device='cuda:1')
# current error is:  tensor(0.0115, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-2.4688, device='cuda:1')
# current error is:  tensor(0.0132, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-2.4436, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-2.6248, device='cuda:1')
# current error is:  tensor(0.0100, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-2.3674, device='cuda:1')
# current error is:  tensor(0.0125, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-2.5926, device='cuda:1')
# current error is:  tensor(0.0107, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-2.6195, device='cuda:1')
# current error is:  tensor(0.0137, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-2.4187, device='cuda:1')
# current error is:  tensor(0.0104, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-2.3237, device='cuda:1')
# current error is:  tensor(0.0106, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-2.4239, device='cuda:1')
# current error is:  tensor(0.0103, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-2.5504, device='cuda:1')
# current error is:  tensor(0.0092, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-2.4789, device='cuda:1')
# current error is:  tensor(0.0180, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-2.2686, device='cuda:1')
# current error is:  tensor(0.0097, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-2.2240, device='cuda:1')
# current error is:  tensor(0.0123, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-2.8278, device='cuda:1')
# current error is:  tensor(0.0132, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-2.5768, device='cuda:1')
# current error is:  tensor(0.0125, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-2.3606, device='cuda:1')
# current error is:  tensor(0.0122, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-2.5033, device='cuda:1')
# current error is:  tensor(0.0095, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-2.3506, device='cuda:1')
# current error is:  tensor(0.0093, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-2.2046, device='cuda:1')
# current error is:  tensor(0.0113, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-2.5972, device='cuda:1')
# current error is:  tensor(0.0095, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-2.4377, device='cuda:1')
# current error is:  tensor(0.0107, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-2.5211, device='cuda:1')
# current error is:  tensor(0.0191, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-2.6143, device='cuda:1')
# current error is:  tensor(0.0158, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-2.5184, device='cuda:1')
# current error is:  tensor(0.0101, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-2.1743, device='cuda:1')
# current error is:  tensor(0.0154, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-2.3837, device='cuda:1')
# current error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-2.5165, device='cuda:1')
# current error is:  tensor(0.0151, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-2.7693, device='cuda:1')
# current error is:  tensor(0.0103, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-2.2595, device='cuda:1')
# current error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-2.3131, device='cuda:1')
# current error is:  tensor(0.0149, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-2.3308, device='cuda:1')
# current error is:  tensor(0.0160, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-2.4597, device='cuda:1')
# current error is:  tensor(0.0093, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-2.6086, device='cuda:1')
# current error is:  tensor(0.0209, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-2.5176, device='cuda:1')
# current error is:  tensor(0.0099, device='cuda:1')
# total time is:  85.74380469322205 seconds

# %%
np.save("unit_DRM_loss_1d.npy", loss_record)
np.save("unit_DRM_error_1d.npy", error_record)
