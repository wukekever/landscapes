# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
from math import *
import time

# %%
torch.cuda.set_device(1)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build neural network
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        self.layer1 = torch.nn.Linear(layer_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        y = self.layer_in(x)
        y = activation(self.layer2(activation(self.layer1(y)))) 
        output = self.layer_out(y)
        return output

# %%
dimension = 1

# %%
input_width,layer_width = dimension, 6

# %%
net = Net(input_width,layer_width).cuda() # network for u on gpu

# %%
# defination of exact solution
def u_ex(x):     
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    return u_temp.reshape([x.size()[0], 1])

# %%
# defination of f(x)
def f(x):
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    f_temp = dimension * pi**2 * u_temp 
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp.cuda()

# %%
def model(x):
    x_temp = x.cuda()
    D_x_0 = torch.prod(x_temp, axis = 1).reshape([x.size()[0], 1]) 
    D_x_1 = torch.prod(1.0 - x_temp, axis = 1).reshape([x.size()[0], 1]) 
    model_u_temp = D_x_0 * D_x_1 * net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
initialize_weights(net)

# %%
# loss function to DGM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape).cuda(), create_graph = True)
    laplace_u = torch.zeros([len(grad_u_hat[0]), 1]).cuda()
    for index in range(dimension):
        p_temp = grad_u_hat[0][:, index].reshape([len(grad_u_hat[0]), 1])
        temp = torch.autograd.grad(outputs = p_temp, inputs = x, grad_outputs = torch.ones(p_temp.shape).cuda(), create_graph = True, allow_unused = True)[0]
        laplace_u = temp[:, index].reshape([len(grad_u_hat[0]), 1]) + laplace_u
        part_2 = torch.sum((-laplace_u - f(x))**2)  / len(x)
    return part_2

# %%
def relative_l2_error():
    data_size_temp = 200
    x = generate_sample(data_size_temp).cuda() 
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
optimizer = optim.Adam(net.parameters())

# %%
epoch = 5000
data_size = 1000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size).cuda()
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    np.save("unit_DGM_loss_1d.npy", loss_record)
    np.save("unit_DGM_error_1d.npy", error_record)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    if i == epoch - 1:
        # save model parameters
        torch.save(net.state_dict(), 'net_params_DGM.pkl')
        
    loss.backward()
    optimizer.step() 
    torch.cuda.empty_cache() # clear memory
    
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(50.3734, device='cuda:1')
# current error is:  tensor(1.0150, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(40.1536, device='cuda:1')
# current error is:  tensor(0.9368, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(31.9403, device='cuda:1')
# current error is:  tensor(0.8142, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(18.6228, device='cuda:1')
# current error is:  tensor(0.5935, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(11.0664, device='cuda:1')
# current error is:  tensor(0.3196, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(8.8571, device='cuda:1')
# current error is:  tensor(0.2359, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(8.3582, device='cuda:1')
# current error is:  tensor(0.1924, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(7.3269, device='cuda:1')
# current error is:  tensor(0.1771, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(4.4141, device='cuda:1')
# current error is:  tensor(0.1479, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(1.3389, device='cuda:1')
# current error is:  tensor(0.0794, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(0.3573, device='cuda:1')
# current error is:  tensor(0.0206, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(0.1497, device='cuda:1')
# current error is:  tensor(0.0118, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(0.0761, device='cuda:1')
# current error is:  tensor(0.0074, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(0.0353, device='cuda:1')
# current error is:  tensor(0.0042, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(0.0263, device='cuda:1')
# current error is:  tensor(0.0026, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(0.0208, device='cuda:1')
# current error is:  tensor(0.0023, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(0.0184, device='cuda:1')
# current error is:  tensor(0.0018, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(0.0174, device='cuda:1')
# current error is:  tensor(0.0015, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(0.0173, device='cuda:1')
# current error is:  tensor(0.0015, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(0.0158, device='cuda:1')
# current error is:  tensor(0.0015, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(0.0149, device='cuda:1')
# current error is:  tensor(0.0013, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(0.0140, device='cuda:1')
# current error is:  tensor(0.0014, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(0.0134, device='cuda:1')
# current error is:  tensor(0.0013, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(0.0122, device='cuda:1')
# current error is:  tensor(0.0011, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(0.0112, device='cuda:1')
# current error is:  tensor(0.0012, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(0.0107, device='cuda:1')
# current error is:  tensor(0.0014, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(0.0100, device='cuda:1')
# current error is:  tensor(0.0012, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(0.0103, device='cuda:1')
# current error is:  tensor(0.0011, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(0.0098, device='cuda:1')
# current error is:  tensor(0.0011, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(0.0088, device='cuda:1')
# current error is:  tensor(0.0010, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(0.0082, device='cuda:1')
# current error is:  tensor(0.0013, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(0.0079, device='cuda:1')
# current error is:  tensor(0.0010, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(0.0073, device='cuda:1')
# current error is:  tensor(0.0011, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(0.0073, device='cuda:1')
# current error is:  tensor(0.0010, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(0.0065, device='cuda:1')
# current error is:  tensor(0.0010, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(0.0060, device='cuda:1')
# current error is:  tensor(0.0008, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(0.0055, device='cuda:1')
# current error is:  tensor(0.0009, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(0.0053, device='cuda:1')
# current error is:  tensor(0.0009, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(0.0049, device='cuda:1')
# current error is:  tensor(0.0008, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(0.0043, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(0.0045, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(0.0041, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(0.0035, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(0.0035, device='cuda:1')
# current error is:  tensor(0.0008, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(0.0033, device='cuda:1')
# current error is:  tensor(0.0006, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(0.0029, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(0.0026, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(0.0025, device='cuda:1')
# current error is:  tensor(0.0007, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(0.0022, device='cuda:1')
# current error is:  tensor(0.0005, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(0.0021, device='cuda:1')
# current error is:  tensor(0.0005, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(0.0020, device='cuda:1')
# current error is:  tensor(0.0005, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(0.0018, device='cuda:1')
# current error is:  tensor(0.0005, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(0.0015, device='cuda:1')
# current error is:  tensor(0.0004, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(0.0015, device='cuda:1')
# current error is:  tensor(0.0004, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(0.0013, device='cuda:1')
# current error is:  tensor(0.0004, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(0.0011, device='cuda:1')
# current error is:  tensor(0.0004, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(0.0010, device='cuda:1')
# current error is:  tensor(0.0004, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(0.0009, device='cuda:1')
# current error is:  tensor(0.0003, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(0.0008, device='cuda:1')
# current error is:  tensor(0.0003, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(0.0008, device='cuda:1')
# current error is:  tensor(0.0003, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(0.0006, device='cuda:1')
# current error is:  tensor(0.0003, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(0.0006, device='cuda:1')
# current error is:  tensor(0.0003, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(0.0005, device='cuda:1')
# current error is:  tensor(0.0002, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(0.0004, device='cuda:1')
# current error is:  tensor(0.0002, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(0.0004, device='cuda:1')
# current error is:  tensor(0.0003, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(0.0003, device='cuda:1')
# current error is:  tensor(0.0002, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(0.0003, device='cuda:1')
# current error is:  tensor(0.0002, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(0.0003, device='cuda:1')
# current error is:  tensor(0.0002, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(0.0002, device='cuda:1')
# current error is:  tensor(0.0001, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(0.0002, device='cuda:1')
# current error is:  tensor(0.0001, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(0.0001, device='cuda:1')
# current error is:  tensor(0.0001, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(0.0001, device='cuda:1')
# current error is:  tensor(0.0001, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(0.0001, device='cuda:1')
# current error is:  tensor(0.0001, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(9.3192e-05, device='cuda:1')
# current error is:  tensor(9.3107e-05, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(7.1202e-05, device='cuda:1')
# current error is:  tensor(0.0001, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(6.2955e-05, device='cuda:1')
# current error is:  tensor(7.7403e-05, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(5.7393e-05, device='cuda:1')
# current error is:  tensor(6.9889e-05, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(4.7895e-05, device='cuda:1')
# current error is:  tensor(7.7362e-05, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(4.1450e-05, device='cuda:1')
# current error is:  tensor(0.0001, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(3.4068e-05, device='cuda:1')
# current error is:  tensor(4.7747e-05, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(3.4907e-05, device='cuda:1')
# current error is:  tensor(6.5978e-05, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(2.6847e-05, device='cuda:1')
# current error is:  tensor(9.5686e-05, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(2.1225e-05, device='cuda:1')
# current error is:  tensor(3.9100e-05, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(2.2738e-05, device='cuda:1')
# current error is:  tensor(3.6475e-05, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(2.0057e-05, device='cuda:1')
# current error is:  tensor(2.8518e-05, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(2.0607e-05, device='cuda:1')
# current error is:  tensor(2.8017e-05, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(1.9571e-05, device='cuda:1')
# current error is:  tensor(2.6234e-05, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(1.4617e-05, device='cuda:1')
# current error is:  tensor(2.4121e-05, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(1.4205e-05, device='cuda:1')
# current error is:  tensor(2.0795e-05, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(1.3399e-05, device='cuda:1')
# current error is:  tensor(3.2459e-05, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(1.2102e-05, device='cuda:1')
# current error is:  tensor(2.1657e-05, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(1.1863e-05, device='cuda:1')
# current error is:  tensor(2.4113e-05, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(1.3645e-05, device='cuda:1')
# current error is:  tensor(2.5905e-05, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(1.2950e-05, device='cuda:1')
# current error is:  tensor(2.2288e-05, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(1.1097e-05, device='cuda:1')
# current error is:  tensor(1.6650e-05, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(1.3731e-05, device='cuda:1')
# current error is:  tensor(2.3878e-05, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(1.0419e-05, device='cuda:1')
# current error is:  tensor(2.5638e-05, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(1.1751e-05, device='cuda:1')
# current error is:  tensor(1.7451e-05, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(9.7958e-06, device='cuda:1')
# current error is:  tensor(3.2050e-05, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(9.9336e-06, device='cuda:1')
# current error is:  tensor(1.6768e-05, device='cuda:1')
# total time is:  127.07423233985901 seconds

# %%
np.save("unit_DGM_loss_1d.npy", loss_record)
np.save("unit_DGM_error_1d.npy", error_record)
