# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
from math import *
import time

# %%
torch.cuda.set_device(1)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build neural network
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        self.layer1 = torch.nn.Linear(layer_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        y = self.layer_in(x)
        y = activation(self.layer2(activation(self.layer1(y)))) 
        output = self.layer_out(y)
        return output

# %%
dimension = 1

# %%
input_width,layer_width = dimension, 6

# %%
net = Net(input_width,layer_width).cuda() # network for u on gpu

# %%
# defination of exact solution
def u_ex(x):     
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    return u_temp.reshape([x.size()[0], 1])

# %%
# defination of f(x)
def f(x):
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    f_temp = dimension * pi**2 * u_temp 
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp.cuda()

# %%
def model(x):
    x_temp = x.cuda()
    D_x_0 = torch.prod(x_temp, axis = 1).reshape([x.size()[0], 1]) 
    D_x_1 = torch.prod(1.0 - x_temp, axis = 1).reshape([x.size()[0], 1]) 
    model_u_temp = D_x_0 * D_x_1 * net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
initialize_weights(net)

# %%
# loss function to DRM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape).cuda(), create_graph = True)
    grad_u_sq = ((grad_u_hat[0]**2).sum(1)).reshape([len(grad_u_hat[0]), 1])
    part = torch.sum(0.5 * grad_u_sq  - f(x) * u_hat)  / len(x)
    return part

# %%
def relative_l2_error():
    data_size_temp = 200
    x = generate_sample(data_size_temp).cuda() 
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
optimizer = optim.Adam(net.parameters())

# %%
epoch = 5000
data_size = 1000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size).cuda()
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    np.save("unit_DRM_loss_1d.npy", loss_record)
    np.save("unit_DRM_error_1d.npy", error_record)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    if i == epoch - 1:
        # save model parameters
        torch.save(net.state_dict(), 'net_params_DRM.pkl')
        
    loss.backward()
    optimizer.step() 
    torch.cuda.empty_cache() # clear memory
    
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(0.3512, device='cuda:1')
# current error is:  tensor(1.0674, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(-0.0687, device='cuda:1')
# current error is:  tensor(0.9875, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(-0.3164, device='cuda:1')
# current error is:  tensor(0.9320, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(-0.6575, device='cuda:1')
# current error is:  tensor(0.8546, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(-1.2670, device='cuda:1')
# current error is:  tensor(0.6941, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(-1.9532, device='cuda:1')
# current error is:  tensor(0.3524, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(-2.3802, device='cuda:1')
# current error is:  tensor(0.1727, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(-2.7192, device='cuda:1')
# current error is:  tensor(0.1503, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(-2.2423, device='cuda:1')
# current error is:  tensor(0.1299, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(-2.4549, device='cuda:1')
# current error is:  tensor(0.1182, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(-2.5988, device='cuda:1')
# current error is:  tensor(0.0884, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(-2.2233, device='cuda:1')
# current error is:  tensor(0.0733, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(-2.3560, device='cuda:1')
# current error is:  tensor(0.0751, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(-2.4038, device='cuda:1')
# current error is:  tensor(0.0610, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(-2.3176, device='cuda:1')
# current error is:  tensor(0.0528, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(-2.4896, device='cuda:1')
# current error is:  tensor(0.0347, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(-2.5227, device='cuda:1')
# current error is:  tensor(0.0382, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(-2.3501, device='cuda:1')
# current error is:  tensor(0.0346, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(-2.0480, device='cuda:1')
# current error is:  tensor(0.0358, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(-2.6560, device='cuda:1')
# current error is:  tensor(0.0320, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-2.2632, device='cuda:1')
# current error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-2.6598, device='cuda:1')
# current error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-2.2830, device='cuda:1')
# current error is:  tensor(0.0400, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-2.3961, device='cuda:1')
# current error is:  tensor(0.0286, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-2.0485, device='cuda:1')
# current error is:  tensor(0.0483, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-2.2725, device='cuda:1')
# current error is:  tensor(0.0333, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-2.5552, device='cuda:1')
# current error is:  tensor(0.0292, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-2.4992, device='cuda:1')
# current error is:  tensor(0.0310, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-2.4136, device='cuda:1')
# current error is:  tensor(0.0264, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-2.6131, device='cuda:1')
# current error is:  tensor(0.0253, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-2.4408, device='cuda:1')
# current error is:  tensor(0.0247, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-2.7829, device='cuda:1')
# current error is:  tensor(0.0247, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-2.4962, device='cuda:1')
# current error is:  tensor(0.0284, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-2.3572, device='cuda:1')
# current error is:  tensor(0.0301, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-2.3207, device='cuda:1')
# current error is:  tensor(0.0196, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-2.1711, device='cuda:1')
# current error is:  tensor(0.0199, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-2.4159, device='cuda:1')
# current error is:  tensor(0.0176, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-2.4839, device='cuda:1')
# current error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-2.4363, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-2.5581, device='cuda:1')
# current error is:  tensor(0.0115, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-1.9593, device='cuda:1')
# current error is:  tensor(0.0132, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-2.5212, device='cuda:1')
# current error is:  tensor(0.0267, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-2.3835, device='cuda:1')
# current error is:  tensor(0.0103, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-2.2784, device='cuda:1')
# current error is:  tensor(0.0081, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-2.3997, device='cuda:1')
# current error is:  tensor(0.0081, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-2.4758, device='cuda:1')
# current error is:  tensor(0.0333, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-2.5233, device='cuda:1')
# current error is:  tensor(0.0193, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-2.3412, device='cuda:1')
# current error is:  tensor(0.0055, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-2.2433, device='cuda:1')
# current error is:  tensor(0.0087, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-2.3200, device='cuda:1')
# current error is:  tensor(0.0043, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-2.5977, device='cuda:1')
# current error is:  tensor(0.0049, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-2.4624, device='cuda:1')
# current error is:  tensor(0.0055, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-2.4118, device='cuda:1')
# current error is:  tensor(0.0351, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-2.5861, device='cuda:1')
# current error is:  tensor(0.0195, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-2.3381, device='cuda:1')
# current error is:  tensor(0.0036, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-2.5061, device='cuda:1')
# current error is:  tensor(0.0112, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-2.2809, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-2.4331, device='cuda:1')
# current error is:  tensor(0.0151, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-2.4174, device='cuda:1')
# current error is:  tensor(0.0066, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-2.6555, device='cuda:1')
# current error is:  tensor(0.0073, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-2.5059, device='cuda:1')
# current error is:  tensor(0.0065, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-2.5149, device='cuda:1')
# current error is:  tensor(0.0036, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-2.4566, device='cuda:1')
# current error is:  tensor(0.0089, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-2.3841, device='cuda:1')
# current error is:  tensor(0.0162, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-2.1386, device='cuda:1')
# current error is:  tensor(0.0110, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-2.6041, device='cuda:1')
# current error is:  tensor(0.0125, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-2.6233, device='cuda:1')
# current error is:  tensor(0.0058, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-2.5431, device='cuda:1')
# current error is:  tensor(0.0134, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-2.4773, device='cuda:1')
# current error is:  tensor(0.0210, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-2.3992, device='cuda:1')
# current error is:  tensor(0.0183, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-2.5888, device='cuda:1')
# current error is:  tensor(0.0212, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-2.7899, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-2.4770, device='cuda:1')
# current error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-2.4360, device='cuda:1')
# current error is:  tensor(0.0059, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-2.3310, device='cuda:1')
# current error is:  tensor(0.0215, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-2.5540, device='cuda:1')
# current error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-2.4706, device='cuda:1')
# current error is:  tensor(0.0040, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-2.5907, device='cuda:1')
# current error is:  tensor(0.0106, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-2.7116, device='cuda:1')
# current error is:  tensor(0.0036, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-2.2807, device='cuda:1')
# current error is:  tensor(0.0030, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-2.2612, device='cuda:1')
# current error is:  tensor(0.0052, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-2.3375, device='cuda:1')
# current error is:  tensor(0.0117, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-2.5716, device='cuda:1')
# current error is:  tensor(0.0036, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-2.5118, device='cuda:1')
# current error is:  tensor(0.0139, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-2.6163, device='cuda:1')
# current error is:  tensor(0.0061, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-2.6308, device='cuda:1')
# current error is:  tensor(0.0105, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-2.6030, device='cuda:1')
# current error is:  tensor(0.0031, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-2.6213, device='cuda:1')
# current error is:  tensor(0.0047, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-2.7181, device='cuda:1')
# current error is:  tensor(0.0203, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-2.5191, device='cuda:1')
# current error is:  tensor(0.0128, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-2.6498, device='cuda:1')
# current error is:  tensor(0.0191, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-2.2180, device='cuda:1')
# current error is:  tensor(0.0178, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-2.6076, device='cuda:1')
# current error is:  tensor(0.0145, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-2.7694, device='cuda:1')
# current error is:  tensor(0.0107, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-2.4382, device='cuda:1')
# current error is:  tensor(0.0196, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-2.5914, device='cuda:1')
# current error is:  tensor(0.0033, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-2.7919, device='cuda:1')
# current error is:  tensor(0.0119, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-2.7000, device='cuda:1')
# current error is:  tensor(0.0109, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-2.5211, device='cuda:1')
# current error is:  tensor(0.0130, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-2.5133, device='cuda:1')
# current error is:  tensor(0.0158, device='cuda:1')
# total time is:  87.61614346504211 seconds

# %%
np.save("unit_DRM_loss_1d.npy", loss_record)
np.save("unit_DRM_error_1d.npy", error_record)
