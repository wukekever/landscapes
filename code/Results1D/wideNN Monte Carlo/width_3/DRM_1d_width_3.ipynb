# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
from math import *
import time

# %%
torch.cuda.set_device(1)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build neural network
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        self.layer1 = torch.nn.Linear(layer_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        y = self.layer_in(x)
        y = activation(self.layer2(activation(self.layer1(y)))) 
        output = self.layer_out(y)
        return output

# %%
dimension = 1

# %%
input_width,layer_width = dimension, 3

# %%
net = Net(input_width,layer_width).cuda() # network for u on gpu

# %%
# defination of exact solution
def u_ex(x):     
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    return u_temp.reshape([x.size()[0], 1])

# %%
# defination of f(x)
def f(x):
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    f_temp = dimension * pi**2 * u_temp 
    return f_temp.reshape([x.size()[0],1])

# %%
# generate points by random
def generate_sample(data_size):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp.cuda()

# %%
def model(x):
    x_temp = x.cuda()
    D_x_0 = torch.prod(x_temp, axis = 1).reshape([x.size()[0], 1]) 
    D_x_1 = torch.prod(1.0 - x_temp, axis = 1).reshape([x.size()[0], 1]) 
    model_u_temp = D_x_0 * D_x_1 * net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
initialize_weights(net)

# %%
# loss function to DRM by auto differential
def loss_function(x):
#     x = generate_sample(data_size).cuda()
#     x.requires_grad = True
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape).cuda(), create_graph = True)
    grad_u_sq = ((grad_u_hat[0]**2).sum(1)).reshape([len(grad_u_hat[0]), 1])
    part = torch.sum(0.5 * grad_u_sq  - f(x) * u_hat)  / len(x)
    return part

# %%
def relative_l2_error():
    data_size_temp = 200
    x = generate_sample(data_size_temp).cuda() 
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
optimizer = optim.Adam(net.parameters())

# %%
epoch = 5000
data_size = 1000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size).cuda()
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    np.save("unit_DRM_loss_1d.npy", loss_record)
    np.save("unit_DRM_error_1d.npy", error_record)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    if i == epoch - 1:
        # save model parameters
        torch.save(net.state_dict(), 'net_params_DRM.pkl')
        
    loss.backward()
    optimizer.step() 
    torch.cuda.empty_cache() # clear memory
    
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(0.0242, device='cuda:1')
# current error is:  tensor(1.0051, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(-0.1102, device='cuda:1')
# current error is:  tensor(0.9780, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(-0.2896, device='cuda:1')
# current error is:  tensor(0.9411, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(-0.5654, device='cuda:1')
# current error is:  tensor(0.8771, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(-1.0288, device='cuda:1')
# current error is:  tensor(0.7666, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(-1.5511, device='cuda:1')
# current error is:  tensor(0.6133, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(-2.1238, device='cuda:1')
# current error is:  tensor(0.4059, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(-2.3872, device='cuda:1')
# current error is:  tensor(0.2334, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(-1.9384, device='cuda:1')
# current error is:  tensor(0.1520, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(-2.3219, device='cuda:1')
# current error is:  tensor(0.1230, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(-2.4183, device='cuda:1')
# current error is:  tensor(0.1061, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(-2.2068, device='cuda:1')
# current error is:  tensor(0.0877, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(-2.2310, device='cuda:1')
# current error is:  tensor(0.0796, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(-2.4734, device='cuda:1')
# current error is:  tensor(0.0683, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(-2.5502, device='cuda:1')
# current error is:  tensor(0.0663, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(-2.4904, device='cuda:1')
# current error is:  tensor(0.0517, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(-2.4528, device='cuda:1')
# current error is:  tensor(0.0437, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(-2.6270, device='cuda:1')
# current error is:  tensor(0.0459, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(-2.5348, device='cuda:1')
# current error is:  tensor(0.0412, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(-2.5583, device='cuda:1')
# current error is:  tensor(0.0323, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-2.3151, device='cuda:1')
# current error is:  tensor(0.0282, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-2.2415, device='cuda:1')
# current error is:  tensor(0.0270, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-2.4577, device='cuda:1')
# current error is:  tensor(0.0231, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-2.7679, device='cuda:1')
# current error is:  tensor(0.0249, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-2.8531, device='cuda:1')
# current error is:  tensor(0.0214, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-2.8440, device='cuda:1')
# current error is:  tensor(0.0173, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-2.5865, device='cuda:1')
# current error is:  tensor(0.0197, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-2.3928, device='cuda:1')
# current error is:  tensor(0.0163, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-2.5156, device='cuda:1')
# current error is:  tensor(0.0178, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-2.6189, device='cuda:1')
# current error is:  tensor(0.0157, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-2.3457, device='cuda:1')
# current error is:  tensor(0.0263, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-2.4131, device='cuda:1')
# current error is:  tensor(0.0131, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-2.3629, device='cuda:1')
# current error is:  tensor(0.0183, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-2.3940, device='cuda:1')
# current error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-2.4803, device='cuda:1')
# current error is:  tensor(0.0139, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-2.5483, device='cuda:1')
# current error is:  tensor(0.0116, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-2.3814, device='cuda:1')
# current error is:  tensor(0.0119, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-2.4800, device='cuda:1')
# current error is:  tensor(0.0118, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-2.4092, device='cuda:1')
# current error is:  tensor(0.0149, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-2.6351, device='cuda:1')
# current error is:  tensor(0.0118, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-2.3135, device='cuda:1')
# current error is:  tensor(0.0106, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-2.4787, device='cuda:1')
# current error is:  tensor(0.0151, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-2.2731, device='cuda:1')
# current error is:  tensor(0.0166, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-2.4053, device='cuda:1')
# current error is:  tensor(0.0124, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-2.1840, device='cuda:1')
# current error is:  tensor(0.0106, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-2.4390, device='cuda:1')
# current error is:  tensor(0.0142, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-2.3699, device='cuda:1')
# current error is:  tensor(0.0110, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-2.5578, device='cuda:1')
# current error is:  tensor(0.0120, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-2.7043, device='cuda:1')
# current error is:  tensor(0.0175, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-2.2166, device='cuda:1')
# current error is:  tensor(0.0094, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-2.5080, device='cuda:1')
# current error is:  tensor(0.0117, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-2.6062, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-2.3828, device='cuda:1')
# current error is:  tensor(0.0133, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-2.4555, device='cuda:1')
# current error is:  tensor(0.0117, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-2.4830, device='cuda:1')
# current error is:  tensor(0.0089, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-2.4472, device='cuda:1')
# current error is:  tensor(0.0106, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-2.2477, device='cuda:1')
# current error is:  tensor(0.0104, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-2.5299, device='cuda:1')
# current error is:  tensor(0.0081, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-2.4603, device='cuda:1')
# current error is:  tensor(0.0083, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-2.5556, device='cuda:1')
# current error is:  tensor(0.0079, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-2.5626, device='cuda:1')
# current error is:  tensor(0.0118, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-2.6358, device='cuda:1')
# current error is:  tensor(0.0100, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-2.8615, device='cuda:1')
# current error is:  tensor(0.0085, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-2.6076, device='cuda:1')
# current error is:  tensor(0.0214, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-2.5164, device='cuda:1')
# current error is:  tensor(0.0087, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-2.6668, device='cuda:1')
# current error is:  tensor(0.0077, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-2.6137, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-2.4825, device='cuda:1')
# current error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-2.4643, device='cuda:1')
# current error is:  tensor(0.0074, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-2.3758, device='cuda:1')
# current error is:  tensor(0.0125, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-2.6223, device='cuda:1')
# current error is:  tensor(0.0073, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-2.2932, device='cuda:1')
# current error is:  tensor(0.0146, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-2.3882, device='cuda:1')
# current error is:  tensor(0.0114, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-2.6626, device='cuda:1')
# current error is:  tensor(0.0140, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-2.4270, device='cuda:1')
# current error is:  tensor(0.0064, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-2.4974, device='cuda:1')
# current error is:  tensor(0.0152, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-2.2661, device='cuda:1')
# current error is:  tensor(0.0097, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-2.3672, device='cuda:1')
# current error is:  tensor(0.0115, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-2.4214, device='cuda:1')
# current error is:  tensor(0.0250, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-2.6527, device='cuda:1')
# current error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-2.3088, device='cuda:1')
# current error is:  tensor(0.0083, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-2.4941, device='cuda:1')
# current error is:  tensor(0.0088, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-2.4260, device='cuda:1')
# current error is:  tensor(0.0091, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-2.4305, device='cuda:1')
# current error is:  tensor(0.0088, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-2.5171, device='cuda:1')
# current error is:  tensor(0.0068, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-2.5240, device='cuda:1')
# current error is:  tensor(0.0195, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-2.5019, device='cuda:1')
# current error is:  tensor(0.0112, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-2.5057, device='cuda:1')
# current error is:  tensor(0.0082, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-2.4317, device='cuda:1')
# current error is:  tensor(0.0103, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-2.3003, device='cuda:1')
# current error is:  tensor(0.0117, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-2.4608, device='cuda:1')
# current error is:  tensor(0.0178, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-2.2553, device='cuda:1')
# current error is:  tensor(0.0129, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-2.3419, device='cuda:1')
# current error is:  tensor(0.0050, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-2.2370, device='cuda:1')
# current error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-2.5340, device='cuda:1')
# current error is:  tensor(0.0092, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-2.7632, device='cuda:1')
# current error is:  tensor(0.0080, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-2.2664, device='cuda:1')
# current error is:  tensor(0.0092, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-2.2934, device='cuda:1')
# current error is:  tensor(0.0160, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-2.5800, device='cuda:1')
# current error is:  tensor(0.0086, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-2.4489, device='cuda:1')
# current error is:  tensor(0.0114, device='cuda:1')
# total time is:  80.57220721244812 seconds

# %%
np.save("unit_DRM_loss_1d.npy", loss_record)
np.save("unit_DRM_error_1d.npy", error_record)
