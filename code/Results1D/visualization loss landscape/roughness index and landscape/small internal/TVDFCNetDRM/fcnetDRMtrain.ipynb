# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from  torch.optim import lr_scheduler
import numpy as np
import matplotlib.pyplot as plt
from math import *
import time

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build ResNet with one blocks
class Net(nn.Module):
    def __init__(self,input_size,width):
        super(Net,self).__init__()
        self.layer_in = nn.Linear(input_size,width)
        self.layer_1 = nn.Linear(width,width)
        self.layer_2 = nn.Linear(width,width)
        self.layer_out = nn.Linear(width,1)
    def forward(self,x):
        output = self.layer_in(x)
        output = activation(self.layer_2(activation(self.layer_1(output)))) # residual block 1
        output = self.layer_out(output)
        return output

# %%
input_size = 1
width = 4
net = Net(input_size,width)

# %%
def model(x):
    return x * (x - 1.0) * net(x)

# %%
# exact solution
def u_ex(x):  
    return torch.sin(pi*x)

# %%
# f(x)
def f(x):
    return pi**2 * torch.sin(pi*x)

# %%
grid_num = 100
x = torch.zeros(grid_num + 1, input_size)
for index in range(grid_num + 1):
    x[index] = index * 1 / grid_num

# %%
optimizer = optim.Adam(net.parameters(), lr = 0.05)
scheduler = lr_scheduler.StepLR(optimizer, 50, 0.9) # every 100 epoch, learning rate * 0.1

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
# loss function to DRM by auto differential
def loss_function(x):
    h = 1 / grid_num
    sum_0 = 0.0
    sum_1 = 0.0
    sum_2 = 0.0
    sum_a = 0.0
    sum_b = 0.0
    for index in range(grid_num):
        x_temp = x[index] + h / 2 
        x_temp.requires_grad = True
        grad_x_temp = torch.autograd.grad(outputs = model(x_temp), inputs = x_temp, grad_outputs = torch.ones(model(x_temp).shape), create_graph = True)
        sum_1 += (0.5*grad_x_temp[0]**2 - f(x_temp)[0]*model(x_temp)[0])
        
    for index in range(1, grid_num):
        x_temp = x[index]
        x_temp.requires_grad = True
        grad_x_temp = torch.autograd.grad(outputs = model(x_temp), inputs = x_temp, grad_outputs = torch.ones(model(x_temp).shape), create_graph = True)
        sum_2 += (0.5*grad_x_temp[0]**2 - f(x_temp)[0]*model(x_temp)[0])
    
    x_temp = x[0]
    x_temp.requires_grad = True
    grad_x_temp = torch.autograd.grad(outputs = model(x_temp), inputs = x_temp, grad_outputs = torch.ones(model(x_temp).shape), create_graph = True)
    sum_a = 0.5*grad_x_temp[0]**2 - f(x_temp)[0]*model(x_temp)[0]
    
    x_temp = x[grid_num]
    x_temp.requires_grad = True
    grad_x_temp = torch.autograd.grad(outputs = model(x_temp), inputs = x_temp, grad_outputs = torch.ones(model(x_temp).shape), create_graph = True)
    sum_a = 0.5*grad_x_temp[0]**2 - f(x_temp)[0]*model(x_temp)[0]
    
    sum_0 = h / 6 * (sum_a + 4 * sum_1 + 2 * sum_2 + sum_b)
    return sum_0

# %%
def error_function(x):
    error = 0.0
    for index in range(len(x)):
        x_temp = x[index]
        error += (model(x_temp)[0] - u_ex(x_temp)[0])**2
    return error / len(x)

# %%
print("Total number of paramerters in networks is {}  ".format(sum(x.numel() for x in net.parameters())))
param_num = sum(x.numel() for x in net.parameters())
# Out:
# Total number of paramerters in networks is 53

# %%
epoch = 500
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = error_function(x)
    error_record[i] = float(error)
    print("current epoch is: ", i)
    print("current loss is: ", loss.detach())
    print("current error is: ", error.detach())
     
    loss.backward()
    optimizer.step() 
    np.save("loss_of_DRM_100.npy", loss_record)
    np.save("error_of_DRM_100.npy", error_record)
    
np.save("loss_of_DRM_100.npy", loss_record)
np.save("error_of_DRM_100.npy", error_record)

time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor([0.1107])
# current error is:  tensor(0.5172)
# current epoch is:  1
# current loss is:  tensor([-0.1292])
# current error is:  tensor(0.4691)
# current epoch is:  2
# current loss is:  tensor([-0.3930])
# current error is:  tensor(0.4160)
# current epoch is:  3
# current loss is:  tensor([-0.6895])
# current error is:  tensor(0.3562)
# current epoch is:  4
# current loss is:  tensor([-1.0245])
# current error is:  tensor(0.2883)
# current epoch is:  5
# current loss is:  tensor([-1.3985])
# current error is:  tensor(0.2120)
# current epoch is:  6
# current loss is:  tensor([-1.7958])
# current error is:  tensor(0.1295)
# current epoch is:  7
# current loss is:  tensor([-2.1534])
# current error is:  tensor(0.0522)
# current epoch is:  8
# current loss is:  tensor([-2.3235])
# current error is:  tensor(0.0077)
# current epoch is:  9
# current loss is:  tensor([-2.1420])
# current error is:  tensor(0.0310)
# current epoch is:  10
# current loss is:  tensor([-1.9792])
# current error is:  tensor(0.0622)
# current epoch is:  11
# current loss is:  tensor([-2.0702])
# current error is:  tensor(0.0514)
# current epoch is:  12
# current loss is:  tensor([-2.2566])
# current error is:  tensor(0.0236)
# current epoch is:  13
# current loss is:  tensor([-2.3913])
# current error is:  tensor(0.0047)
# current epoch is:  14
# current loss is:  tensor([-2.4287])
# current error is:  tensor(0.0027)
# current epoch is:  15
# current loss is:  tensor([-2.3927])
# current error is:  tensor(0.0127)
# current epoch is:  16
# current loss is:  tensor([-2.3396])
# current error is:  tensor(0.0241)
# current epoch is:  17
# current loss is:  tensor([-2.3158])
# current error is:  tensor(0.0289)
# current epoch is:  18
# current loss is:  tensor([-2.3280])
# current error is:  tensor(0.0263)
# current epoch is:  19
# current loss is:  tensor([-2.3626])
# current error is:  tensor(0.0192)
# current epoch is:  20
# current loss is:  tensor([-2.4024])
# current error is:  tensor(0.0109)
# current epoch is:  21
# current loss is:  tensor([-2.4332])
# current error is:  tensor(0.0042)
# current epoch is:  22
# current loss is:  tensor([-2.4469])
# current error is:  tensor(0.0009)
# current epoch is:  23
# current loss is:  tensor([-2.4427])
# current error is:  tensor(0.0012)
# current epoch is:  24
# current loss is:  tensor([-2.4268])
# current error is:  tensor(0.0039)
# current epoch is:  25
# current loss is:  tensor([-2.4103])
# current error is:  tensor(0.0069)
# current epoch is:  26
# current loss is:  tensor([-2.4029])
# current error is:  tensor(0.0082)
# current epoch is:  27
# current loss is:  tensor([-2.4075])
# current error is:  tensor(0.0073)
# current epoch is:  28
# current loss is:  tensor([-2.4201])
# current error is:  tensor(0.0050)
# current epoch is:  29
# current loss is:  tensor([-2.4337])
# current error is:  tensor(0.0025)
# current epoch is:  30
# current loss is:  tensor([-2.4427])
# current error is:  tensor(0.0010)
# current epoch is:  31
# current loss is:  tensor([-2.4451])
# current error is:  tensor(0.0008)
# current epoch is:  32
# current loss is:  tensor([-2.4422])
# current error is:  tensor(0.0016)
# current epoch is:  33
# current loss is:  tensor([-2.4368])
# current error is:  tensor(0.0028)
# current epoch is:  34
# current loss is:  tensor([-2.4319])
# current error is:  tensor(0.0039)
# current epoch is:  35
# current loss is:  tensor([-2.4292])
# current error is:  tensor(0.0045)
# current epoch is:  36
# current loss is:  tensor([-2.4297])
# current error is:  tensor(0.0044)
# current epoch is:  37
# current loss is:  tensor([-2.4328])
# current error is:  tensor(0.0038)
# current epoch is:  38
# current loss is:  tensor([-2.4373])
# current error is:  tensor(0.0028)
# current epoch is:  39
# current loss is:  tensor([-2.4419])
# current error is:  tensor(0.0018)
# current epoch is:  40
# current loss is:  tensor([-2.4450])
# current error is:  tensor(0.0010)
# current epoch is:  41
# current loss is:  tensor([-2.4460])
# current error is:  tensor(0.0007)
# current epoch is:  42
# current loss is:  tensor([-2.4451])
# current error is:  tensor(0.0008)
# current epoch is:  43
# current loss is:  tensor([-2.4432])
# current error is:  tensor(0.0011)
# current epoch is:  44
# current loss is:  tensor([-2.4415])
# current error is:  tensor(0.0014)
# current epoch is:  45
# current loss is:  tensor([-2.4411])
# current error is:  tensor(0.0015)
# current epoch is:  46
# current loss is:  tensor([-2.4423])
# current error is:  tensor(0.0014)
# current epoch is:  47
# current loss is:  tensor([-2.4444])
# current error is:  tensor(0.0011)
# current epoch is:  48
# current loss is:  tensor([-2.4468])
# current error is:  tensor(0.0008)
# current epoch is:  49
# current loss is:  tensor([-2.4487])
# current error is:  tensor(0.0006)
# current epoch is:  50
# current loss is:  tensor([-2.4497])
# current error is:  tensor(0.0007)
# current epoch is:  51
# current loss is:  tensor([-2.4499])
# current error is:  tensor(0.0008)
# current epoch is:  52
# current loss is:  tensor([-2.4498])
# current error is:  tensor(0.0011)
# current epoch is:  53
# current loss is:  tensor([-2.4500])
# current error is:  tensor(0.0012)
# current epoch is:  54
# current loss is:  tensor([-2.4507])
# current error is:  tensor(0.0013)
# current epoch is:  55
# current loss is:  tensor([-2.4521])
# current error is:  tensor(0.0012)
# current epoch is:  56
# current loss is:  tensor([-2.4541])
# current error is:  tensor(0.0011)
# current epoch is:  57
# current loss is:  tensor([-2.4563])
# current error is:  tensor(0.0008)
# current epoch is:  58
# current loss is:  tensor([-2.4584])
# current error is:  tensor(0.0006)
# current epoch is:  59
# current loss is:  tensor([-2.4603])
# current error is:  tensor(0.0005)
# current epoch is:  60
# current loss is:  tensor([-2.4617])
# current error is:  tensor(0.0004)
# current epoch is:  61
# current loss is:  tensor([-2.4627])
# current error is:  tensor(0.0004)
# current epoch is:  62
# current loss is:  tensor([-2.4634])
# current error is:  tensor(0.0005)
# current epoch is:  63
# current loss is:  tensor([-2.4639])
# current error is:  tensor(0.0005)
# current epoch is:  64
# current loss is:  tensor([-2.4644])
# current error is:  tensor(0.0006)
# current epoch is:  65
# current loss is:  tensor([-2.4650])
# current error is:  tensor(0.0006)
# current epoch is:  66
# current loss is:  tensor([-2.4659])
# current error is:  tensor(0.0005)
# current epoch is:  67
# current loss is:  tensor([-2.4672])
# current error is:  tensor(0.0004)
# current epoch is:  68
# current loss is:  tensor([-2.4686])
# current error is:  tensor(0.0003)
# current epoch is:  69
# current loss is:  tensor([-2.4699])
# current error is:  tensor(0.0003)
# current epoch is:  70
# current loss is:  tensor([-2.4708])
# current error is:  tensor(0.0002)
# current epoch is:  71
# current loss is:  tensor([-2.4714])
# current error is:  tensor(0.0001)
# current epoch is:  72
# current loss is:  tensor([-2.4717])
# current error is:  tensor(0.0001)
# current epoch is:  73
# current loss is:  tensor([-2.4718])
# current error is:  tensor(0.0001)
# current epoch is:  74
# current loss is:  tensor([-2.4720])
# current error is:  tensor(0.0001)
# current epoch is:  75
# current loss is:  tensor([-2.4722])
# current error is:  tensor(0.0001)
# current epoch is:  76
# current loss is:  tensor([-2.4724])
# current error is:  tensor(0.0001)
# current epoch is:  77
# current loss is:  tensor([-2.4726])
# current error is:  tensor(0.0001)
# current epoch is:  78
# current loss is:  tensor([-2.4728])
# current error is:  tensor(0.0001)
# current epoch is:  79
# current loss is:  tensor([-2.4731])
# current error is:  tensor(7.7430e-05)
# current epoch is:  80
# current loss is:  tensor([-2.4732])
# current error is:  tensor(5.6280e-05)
# current epoch is:  81
# current loss is:  tensor([-2.4733])
# current error is:  tensor(5.6425e-05)
# current epoch is:  82
# current loss is:  tensor([-2.4733])
# current error is:  tensor(8.0427e-05)
# current epoch is:  83
# current loss is:  tensor([-2.4732])
# current error is:  tensor(0.0001)
# current epoch is:  84
# current loss is:  tensor([-2.4731])
# current error is:  tensor(0.0001)
# current epoch is:  85
# current loss is:  tensor([-2.4732])
# current error is:  tensor(0.0001)
# current epoch is:  86
# current loss is:  tensor([-2.4733])
# current error is:  tensor(0.0001)
# current epoch is:  87
# current loss is:  tensor([-2.4735])
# current error is:  tensor(8.4124e-05)
# current epoch is:  88
# current loss is:  tensor([-2.4736])
# current error is:  tensor(5.8611e-05)
# current epoch is:  89
# current loss is:  tensor([-2.4737])
# current error is:  tensor(4.4538e-05)
# current epoch is:  90
# current loss is:  tensor([-2.4738])
# current error is:  tensor(3.9802e-05)
# current epoch is:  91
# current loss is:  tensor([-2.4739])
# current error is:  tensor(3.9812e-05)
# current epoch is:  92
# current loss is:  tensor([-2.4740])
# current error is:  tensor(4.1115e-05)
# current epoch is:  93
# current loss is:  tensor([-2.4741])
# current error is:  tensor(4.1811e-05)
# current epoch is:  94
# current loss is:  tensor([-2.4742])
# current error is:  tensor(4.0972e-05)
# current epoch is:  95
# current loss is:  tensor([-2.4743])
# current error is:  tensor(3.8580e-05)
# current epoch is:  96
# current loss is:  tensor([-2.4744])
# current error is:  tensor(3.5609e-05)
# current epoch is:  97
# current loss is:  tensor([-2.4745])
# current error is:  tensor(3.3546e-05)
# current epoch is:  98
# current loss is:  tensor([-2.4746])
# current error is:  tensor(3.3555e-05)
# current epoch is:  99
# current loss is:  tensor([-2.4747])
# current error is:  tensor(3.6053e-05)
# current epoch is:  100
# current loss is:  tensor([-2.4747])
# current error is:  tensor(4.0910e-05)
# current epoch is:  101
# current loss is:  tensor([-2.4748])
# current error is:  tensor(4.7479e-05)
# current epoch is:  102
# current loss is:  tensor([-2.4748])
# current error is:  tensor(5.4149e-05)
# current epoch is:  103
# current loss is:  tensor([-2.4748])
# current error is:  tensor(5.8373e-05)
# current epoch is:  104
# current loss is:  tensor([-2.4749])
# current error is:  tensor(5.8045e-05)
# current epoch is:  105
# current loss is:  tensor([-2.4749])
# current error is:  tensor(5.3212e-05)
# current epoch is:  106
# current loss is:  tensor([-2.4750])
# current error is:  tensor(4.6206e-05)
# current epoch is:  107
# current loss is:  tensor([-2.4750])
# current error is:  tensor(3.9898e-05)
# current epoch is:  108
# current loss is:  tensor([-2.4750])
# current error is:  tensor(3.5764e-05)
# current epoch is:  109
# current loss is:  tensor([-2.4751])
# current error is:  tensor(3.3531e-05)
# current epoch is:  110
# current loss is:  tensor([-2.4751])
# current error is:  tensor(3.2283e-05)
# current epoch is:  111
# current loss is:  tensor([-2.4751])
# current error is:  tensor(3.1517e-05)
# current epoch is:  112
# current loss is:  tensor([-2.4751])
# current error is:  tensor(3.1228e-05)
# current epoch is:  113
# current loss is:  tensor([-2.4752])
# current error is:  tensor(3.1419e-05)
# current epoch is:  114
# current loss is:  tensor([-2.4752])
# current error is:  tensor(3.1898e-05)
# current epoch is:  115
# current loss is:  tensor([-2.4752])
# current error is:  tensor(3.2473e-05)
# current epoch is:  116
# current loss is:  tensor([-2.4752])
# current error is:  tensor(3.3120e-05)
# current epoch is:  117
# current loss is:  tensor([-2.4753])
# current error is:  tensor(3.3899e-05)
# current epoch is:  118
# current loss is:  tensor([-2.4753])
# current error is:  tensor(3.4793e-05)
# current epoch is:  119
# current loss is:  tensor([-2.4753])
# current error is:  tensor(3.5689e-05)
# current epoch is:  120
# current loss is:  tensor([-2.4753])
# current error is:  tensor(3.6386e-05)
# current epoch is:  121
# current loss is:  tensor([-2.4754])
# current error is:  tensor(3.6532e-05)
# current epoch is:  122
# current loss is:  tensor([-2.4754])
# current error is:  tensor(3.5698e-05)
# current epoch is:  123
# current loss is:  tensor([-2.4754])
# current error is:  tensor(3.3693e-05)
# current epoch is:  124
# current loss is:  tensor([-2.4754])
# current error is:  tensor(3.0837e-05)
# current epoch is:  125
# current loss is:  tensor([-2.4755])
# current error is:  tensor(2.7830e-05)
# current epoch is:  126
# current loss is:  tensor([-2.4755])
# current error is:  tensor(2.5296e-05)
# current epoch is:  127
# current loss is:  tensor([-2.4755])
# current error is:  tensor(2.3481e-05)
# current epoch is:  128
# current loss is:  tensor([-2.4755])
# current error is:  tensor(2.2345e-05)
# current epoch is:  129
# current loss is:  tensor([-2.4755])
# current error is:  tensor(2.1782e-05)
# current epoch is:  130
# current loss is:  tensor([-2.4755])
# current error is:  tensor(2.1689e-05)
# current epoch is:  131
# current loss is:  tensor([-2.4756])
# current error is:  tensor(2.1898e-05)
# current epoch is:  132
# current loss is:  tensor([-2.4756])
# current error is:  tensor(2.2192e-05)
# current epoch is:  133
# current loss is:  tensor([-2.4756])
# current error is:  tensor(2.2428e-05)
# current epoch is:  134
# current loss is:  tensor([-2.4756])
# current error is:  tensor(2.2597e-05)
# current epoch is:  135
# current loss is:  tensor([-2.4756])
# current error is:  tensor(2.2766e-05)
# current epoch is:  136
# current loss is:  tensor([-2.4756])
# current error is:  tensor(2.2975e-05)
# current epoch is:  137
# current loss is:  tensor([-2.4756])
# current error is:  tensor(2.3194e-05)
# current epoch is:  138
# current loss is:  tensor([-2.4757])
# current error is:  tensor(2.3312e-05)
# current epoch is:  139
# current loss is:  tensor([-2.4757])
# current error is:  tensor(2.3163e-05)
# current epoch is:  140
# current loss is:  tensor([-2.4757])
# current error is:  tensor(2.2620e-05)
# current epoch is:  141
# current loss is:  tensor([-2.4757])
# current error is:  tensor(2.1707e-05)
# current epoch is:  142
# current loss is:  tensor([-2.4757])
# current error is:  tensor(2.0618e-05)
# current epoch is:  143
# current loss is:  tensor([-2.4757])
# current error is:  tensor(1.9607e-05)
# current epoch is:  144
# current loss is:  tensor([-2.4757])
# current error is:  tensor(1.8858e-05)
# current epoch is:  145
# current loss is:  tensor([-2.4757])
# current error is:  tensor(1.8438e-05)
# current epoch is:  146
# current loss is:  tensor([-2.4757])
# current error is:  tensor(1.8327e-05)
# current epoch is:  147
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.8448e-05)
# current epoch is:  148
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.8680e-05)
# current epoch is:  149
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.8908e-05)
# current epoch is:  150
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9075e-05)
# current epoch is:  151
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9191e-05)
# current epoch is:  152
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9295e-05)
# current epoch is:  153
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9403e-05)
# current epoch is:  154
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9493e-05)
# current epoch is:  155
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9499e-05)
# current epoch is:  156
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9349e-05)
# current epoch is:  157
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.9007e-05)
# current epoch is:  158
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.8518e-05)
# current epoch is:  159
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.7981e-05)
# current epoch is:  160
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.7507e-05)
# current epoch is:  161
# current loss is:  tensor([-2.4758])
# current error is:  tensor(1.7167e-05)
# current epoch is:  162
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6979e-05)
# current epoch is:  163
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6911e-05)
# current epoch is:  164
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6906e-05)
# current epoch is:  165
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6906e-05)
# current epoch is:  166
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6881e-05)
# current epoch is:  167
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6837e-05)
# current epoch is:  168
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6795e-05)
# current epoch is:  169
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6766e-05)
# current epoch is:  170
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6739e-05)
# current epoch is:  171
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6679e-05)
# current epoch is:  172
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6548e-05)
# current epoch is:  173
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6332e-05)
# current epoch is:  174
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1.6052e-05)
# current epoch is:  175
# current loss is:  tensor([-2.4759])
# current error is:  tensor(1